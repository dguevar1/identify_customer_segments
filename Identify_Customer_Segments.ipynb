# %% [markdown]
# # Project: Identify Customer Segments
#
# In this project, you will apply unsupervised learning techniques to identify segments of the population that form the core customer base for a mail-order sales company in Germany. These segments can then be used to direct marketing campaigns towards audiences that will have the highest expected rate of returns. The data that you will use has been provided by our partners at Bertelsmann Arvato Analytics, and represents a real-life data science task.
#
# This notebook will help you complete this task by providing a framework within which you will perform your analysis steps. In each step of the project, you will see some text describing the subtask that you will perform, followed by one or more code cells for you to complete your work. **Feel free to add additional code and markdown cells as you go along so that you can explore everything in precise chunks.** The code cells provided in the base template will outline only the major tasks, and will usually not be enough to cover all of the minor tasks that comprise it.
#
# It should be noted that while there will be precise guidelines on how you should handle certain tasks in the project, there will also be places where an exact specification is not provided. **There will be times in the project where you will need to make and justify your own decisions on how to treat the data.** These are places where there may not be only one way to handle the data. In real-life tasks, there may be many valid ways to approach an analysis task. One of the most important things you can do is clearly document your approach so that other scientists can understand the decisions you've made.
#
# At the end of most sections, there will be a Markdown cell labeled **Discussion**. In these cells, you will report your findings for the completed section, as well as document the decisions that you made in your approach to each subtask. **Your project will be evaluated not just on the code used to complete the tasks outlined, but also your communication about your observations and conclusions at each stage.**

# %%
# import libraries here; add more as necessary
from sklearn.decomposition import PCA
from sklearn.impute import SimpleImputer

import datetime
import enum
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import sklearn
import sys
import time

# magic word for producing visualizations in notebook
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# **Import Note**: The classroom currently uses sklearn version 0.19. If you need to use an imputer, it is available in `sklearn.preprocessing.Imputer`, instead of `sklearn.impute` as in newer versions of sklearn.

# %% [markdown]
# The version of Python used with this notebook is printed below:

# %%
print('The Python version is {}.'.format(sys.version))
# Out:
# The Python version is 3.7.6 (default, Jan  8 2020, 20:23:39) [MSC v.1916 64 bit (AMD64)].

# %% [markdown]
# The version of sckit-learn used with this notebook is printed below:

# %%
print('The scikit-learn version is {}.'.format(sklearn.__version__))
# Out:
# The scikit-learn version is 0.22.1.

# %% [markdown]
# ### Step 0: Load the Data
#
# There are four files associated with this project (not including this one):
#
# - `Udacity_AZDIAS_Subset.csv`: Demographics data for the general population of Germany; 891211 persons (rows) x 85 features (columns).
# - `Udacity_CUSTOMERS_Subset.csv`: Demographics data for customers of a mail-order company; 191652 persons (rows) x 85 features (columns).
# - `Data_Dictionary.md`: Detailed information file about the features in the provided datasets.
# - `AZDIAS_Feature_Summary.csv`: Summary of feature attributes for demographics data; 85 features (rows) x 4 columns
#
# Each row of the demographics files represents a single person, but also includes information outside of individuals, including information about their household, building, and neighborhood. You will use this information to cluster the general population into groups with similar demographic properties. Then, you will see how the people in the customers dataset fit into those created clusters. The hope here is that certain clusters are over-represented in the customers data, as compared to the general population; those over-represented clusters will be assumed to be part of the core userbase. This information can then be used for further applications, such as targeting for a marketing campaign.
#
# To start off with, load in the demographics data for the general population into a pandas DataFrame, and do the same for the feature attributes summary. Note, all of the `.csv` data files in this project are semicolon (`;`) delimited, so you'll need an additional argument in your [`read_csv()`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html) call to read in the data properly. Also, considering the size of the main dataset, it may take some time for it to load completely.
#
# Once the dataset is loaded, it's recommended that you take a little bit of time just browsing the general structure of the dataset and feature summary file. You'll be getting deep into the innards of the cleaning in the first major step of the project, so gaining some general familiarity can help you get your bearings.

# %%
# Shared data delimiter.
data_delimiter = ";"

# Load in the general demographics data.
general_demographics_file = "Udacity_AZDIAS_Subset.csv"
general_demographics = pd.read_csv(general_demographics_file, sep=data_delimiter)

# Load in the feature summary data.
feature_summary_file = "AZDIAS_Feature_Summary.csv"
feature_summary = pd.read_csv(feature_summary_file, sep=data_delimiter)

# %%
# Check the structure of the data after it's loaded (e.g. print the number of
# rows and columns, print the first few rows).

# %% [markdown]
# #### Step 0.1: General Demographics Exploration

# %% [markdown]
# We print out the rows and columns of the general demographics data:

# %%
general_demographics.shape
# Out:
# (891221, 85)

# %% [markdown]
# We print out the first few rows of the general demographics data:

# %%
general_demographics.head()
# Out:
#    AGER_TYP  ALTERSKATEGORIE_GROB  ANREDE_KZ  CJT_GESAMTTYP  \
# 0        -1                     2          1            2.0
# 1        -1                     1          2            5.0
# 2        -1                     3          2            3.0
# 3         2                     4          2            2.0
# 4        -1                     3          1            5.0
#
#    FINANZ_MINIMALIST  FINANZ_SPARER  FINANZ_VORSORGER  FINANZ_ANLEGER  \
# 0                  3              4                 3               5
# 1                  1              5                 2               5
# 2                  1              4                 1               2
# 3                  4              2                 5               2
# 4                  4              3                 4               1
#
#    FINANZ_UNAUFFAELLIGER  FINANZ_HAUSBAUER  ...  PLZ8_ANTG1  PLZ8_ANTG2  \
# 0                      5                 3  ...         NaN         NaN
# ...

# %% [markdown]
# #### Step 0.2: Feature Summary Exploration

# %% [markdown]
# We print out the rows and columns of the feature summary data:

# %%
feature_summary.shape
# Out:
# (85, 4)

# %% [markdown]
# We print out the feature summary data so it can be used as a reference:

# %%
feature_summary.iloc[0:20]
# Out:
#                 attribute information_level         type missing_or_unknown
# 0                AGER_TYP            person  categorical             [-1,0]
# 1    ALTERSKATEGORIE_GROB            person      ordinal           [-1,0,9]
# 2               ANREDE_KZ            person  categorical             [-1,0]
# 3           CJT_GESAMTTYP            person  categorical                [0]
# 4       FINANZ_MINIMALIST            person      ordinal               [-1]
# 5           FINANZ_SPARER            person      ordinal               [-1]
# 6        FINANZ_VORSORGER            person      ordinal               [-1]
# 7          FINANZ_ANLEGER            person      ordinal               [-1]
# 8   FINANZ_UNAUFFAELLIGER            person      ordinal               [-1]
# 9        FINANZ_HAUSBAUER            person      ordinal               [-1]
# 10              FINANZTYP            person  categorical               [-1]
# ...

# %%
feature_summary.iloc[20:40]
# Out:
#                 attribute information_level         type missing_or_unknown
# 20         LP_STATUS_GROB            person  categorical                [0]
# 21       NATIONALITAET_KZ            person  categorical             [-1,0]
# 22  PRAEGENDE_JUGENDJAHRE            person        mixed             [-1,0]
# 23         RETOURTYP_BK_S            person      ordinal                [0]
# 24              SEMIO_SOZ            person      ordinal             [-1,9]
# 25              SEMIO_FAM            person      ordinal             [-1,9]
# 26              SEMIO_REL            person      ordinal             [-1,9]
# 27              SEMIO_MAT            person      ordinal             [-1,9]
# 28             SEMIO_VERT            person      ordinal             [-1,9]
# 29             SEMIO_LUST            person      ordinal             [-1,9]
# 30              SEMIO_ERL            person      ordinal             [-1,9]
# ...

# %%
feature_summary.iloc[40:60]
# Out:
#               attribute information_level         type missing_or_unknown
# 40             TITEL_KZ            person  categorical             [-1,0]
# 41             VERS_TYP            person  categorical               [-1]
# 42             ZABEOTYP            person  categorical             [-1,9]
# 43             ALTER_HH         household     interval                [0]
# 44         ANZ_PERSONEN         household      numeric                 []
# 45            ANZ_TITEL         household      numeric                 []
# 46   HH_EINKOMMEN_SCORE         household      ordinal             [-1,0]
# 47         KK_KUNDENTYP         household  categorical               [-1]
# 48       W_KEIT_KIND_HH         household      ordinal             [-1,0]
# 49       WOHNDAUER_2008         household      ordinal             [-1,0]
# 50  ANZ_HAUSHALTE_AKTIV          building      numeric                [0]
# 51         ANZ_HH_TITEL          building      numeric                 []
# ...

# %%
feature_summary.iloc[60:85]
# Out:
#              attribute information_level     type missing_or_unknown
# 60         KBA05_ANTG1     microcell_rr3  ordinal               [-1]
# 61         KBA05_ANTG2     microcell_rr3  ordinal               [-1]
# 62         KBA05_ANTG3     microcell_rr3  ordinal               [-1]
# 63         KBA05_ANTG4     microcell_rr3  ordinal               [-1]
# 64        KBA05_BAUMAX     microcell_rr3    mixed             [-1,0]
# 65           KBA05_GBZ     microcell_rr3  ordinal             [-1,0]
# 66            BALLRAUM          postcode  ordinal               [-1]
# 67            EWDICHTE          postcode  ordinal               [-1]
# 68          INNENSTADT          postcode  ordinal               [-1]
# 69  GEBAEUDETYP_RASTER        region_rr1  ordinal                 []
# 70                 KKK        region_rr1  ordinal             [-1,0]
# 71          MOBI_REGIO        region_rr1  ordinal                 []
# 72   ONLINE_AFFINITAET        region_rr1  ordinal                 []
# ...

# %% [markdown]
# > **Tip**: Add additional cells to keep everything in reasonably-sized chunks! Keyboard shortcut `esc --> a` (press escape to enter command mode, then press the 'A' key) adds a new cell before the active cell, and `esc --> b` adds a new cell after the active cell. If you need to convert an active cell to a markdown cell, use `esc --> m`. To convert to a code cell, use `esc --> y`.
#
# ## Step 1: Preprocessing
#
# ### Step 1.1: Assess Missing Data
#
# The feature summary file contains a summary of properties for each demographics data column. You will use this file to help you make cleaning decisions during this stage of the project. First of all, you should assess the demographics data in terms of missing data. Pay attention to the following points as you perform your analysis, and take notes on what you observe. Make sure that you fill in the **Discussion** cell with your findings and decisions at the end of each step that has one!
#
# #### Step 1.1.1: Convert Missing Value Codes to NaNs
# The fourth column of the feature attributes summary (loaded in above as `feature_summary`) documents the codes from the data dictionary that indicate missing or unknown data. While the file encodes this as a list (e.g. `[-1,0]`), this will get read in as a string object. You'll need to do a little bit of parsing to make use of it to identify and clean the data. Convert data that matches a 'missing' or 'unknown' value code into a numpy NaN value, i.e. `np.nan`. You might want to see how much data takes on a 'missing' or 'unknown' code and how much data is naturally missing, as a point of interest.
#
# **As one more reminder, you are encouraged to add additional cells to break up your analysis into manageable chunks.**

# %% [markdown]
# #### Missing Data Analysis Before Data Processing

# %% [markdown]
# We are going to check the missing value before any data processing. We start by saving the number of records in the general demographics dataset. We will use this value to calculate the percentage of missing values.

# %%
number_of_general_demographics_records = general_demographics.shape[0]

# %% [markdown]
# We print out the value of `number_of_general_demographics_records` as a sanity check:

# %%
number_of_general_demographics_records
# Out:
# 891221

# %% [markdown]
# To calculate the number of null records per column, we are using the `isnull()` method combined with the `sum()` method.

# %%
null_data_count_per_column = general_demographics.isnull().sum()

# %% [markdown]
# We do a sanity check on the returned results by checking the `shape` property and previewing the data with the `head()` method.

# %%
null_data_count_per_column.shape
# Out:
# (85,)

# %%
null_data_count_per_column.head()
# Out:
# AGER_TYP                   0
# ALTERSKATEGORIE_GROB       0
# ANREDE_KZ                  0
# CJT_GESAMTTYP           4854
# FINANZ_MINIMALIST          0
# dtype: int64

# %% [markdown]
# We calculate the percentage of null data by dividing by the `number_of_general_demographics_records` and mulitplying by 100. We are rounding to two decimal places.

# %%
null_data_percentage_per_column = np.round((null_data_count_per_column/number_of_general_demographics_records)*100,2)

# %% [markdown]
# We do a sanity check on the calculated results by checking the `shape` and previewing the data with the `head()` method.

# %%
null_data_percentage_per_column.shape
# Out:
# (85,)

# %%
null_data_percentage_per_column.head()
# Out:
# AGER_TYP                0.00
# ALTERSKATEGORIE_GROB    0.00
# ANREDE_KZ               0.00
# CJT_GESAMTTYP           0.54
# FINANZ_MINIMALIST       0.00
# dtype: float64

# %% [markdown]
# We create a dataframe containing the null data count and the null data percentage per column.

# %%
data_dictionary = {"null_data_count": null_data_count_per_column, "null_data_percentage" : null_data_percentage_per_column }

# %%
null_data_information_per_column = pd.DataFrame(data=data_dictionary, index=null_data_count_per_column.index)

# %% [markdown]
# We sort the columns by count.

# %%
null_data_information_per_column.sort_values(by='null_data_count', ascending=False, inplace=True)

# %% [markdown]
# We show the dataframe below.

# %%
null_data_information_per_column[0:20]
# Out:
#                   null_data_count  null_data_percentage
# KK_KUNDENTYP               584612                 65.60
# KBA05_GBZ                  133324                 14.96
# KBA05_ANTG1                133324                 14.96
# KBA05_ANTG3                133324                 14.96
# MOBI_REGIO                 133324                 14.96
# KBA05_ANTG2                133324                 14.96
# KBA05_ANTG4                133324                 14.96
# KBA05_BAUMAX               133324                 14.96
# REGIOTYP                   121196                 13.60
# KKK                        121196                 13.60
# PLZ8_HHZ                   116515                 13.07
# PLZ8_BAUMAX                116515                 13.07
# PLZ8_ANTG4                 116515                 13.07
# PLZ8_GBZ                   116515                 13.07
# PLZ8_ANTG2                 116515                 13.07
# PLZ8_ANTG1                 116515                 13.07
# ...

# %%
null_data_information_per_column[20:40]
# Out:
#                      null_data_count  null_data_percentage
# CAMEO_DEU_2015                 98979                 11.11
# CAMEO_DEUG_2015                98979                 11.11
# ARBEIT                         97216                 10.91
# ORTSGR_KLS9                    97216                 10.91
# RELAT_AB                       97216                 10.91
# ANZ_HH_TITEL                   97008                 10.88
# BALLRAUM                       93740                 10.52
# INNENSTADT                     93740                 10.52
# EWDICHTE                       93740                 10.52
# GEBAEUDETYP_RASTER             93155                 10.45
# WOHNLAGE                       93148                 10.45
# ANZ_HAUSHALTE_AKTIV            93148                 10.45
# MIN_GEBAEUDEJAHR               93148                 10.45
# OST_WEST_KZ                    93148                 10.45
# GEBAEUDETYP                    93148                 10.45
# ...

# %%
null_data_information_per_column[40:60]
# Out:
#                       null_data_count  null_data_percentage
# TITEL_KZ                        73499                  8.25
# SOHO_KZ                         73499                  8.25
# HH_EINKOMMEN_SCORE              18348                  2.06
# LP_STATUS_GROB                   4854                  0.54
# ONLINE_AFFINITAET                4854                  0.54
# LP_FAMILIE_FEIN                  4854                  0.54
# LP_STATUS_FEIN                   4854                  0.54
# LP_LEBENSPHASE_FEIN              4854                  0.54
# GFK_URLAUBERTYP                  4854                  0.54
# LP_LEBENSPHASE_GROB              4854                  0.54
# RETOURTYP_BK_S                   4854                  0.54
# CJT_GESAMTTYP                    4854                  0.54
# LP_FAMILIE_GROB                  4854                  0.54
# AGER_TYP                            0                  0.00
# ALTERSKATEGORIE_GROB                0                  0.00
# ...

# %%
null_data_information_per_column[60:85]
# Out:
#                        null_data_count  null_data_percentage
# FINANZ_ANLEGER                       0                   0.0
# FINANZ_UNAUFFAELLIGER                0                   0.0
# FINANZ_HAUSBAUER                     0                   0.0
# FINANZTYP                            0                   0.0
# GEBURTSJAHR                          0                   0.0
# GREEN_AVANTGARDE                     0                   0.0
# HEALTH_TYP                           0                   0.0
# NATIONALITAET_KZ                     0                   0.0
# PRAEGENDE_JUGENDJAHRE                0                   0.0
# SEMIO_FAM                            0                   0.0
# VERS_TYP                             0                   0.0
# SEMIO_REL                            0                   0.0
# SEMIO_MAT                            0                   0.0
# SEMIO_VERT                           0                   0.0
# ...

# %% [markdown]
# #### Convert Missing Or Unknown Data Values To NaNs

# %% [markdown]
# Our goal is to convert missing or unknown data values to Nans. We start by verifying the `missing_or_unknown` column of `feature_summary` is actually a string.

# %%
feature_summary.missing_or_unknown[0]
# Out:
# '[-1,0]'

# %% [markdown]
# We get all the unique values under the `missing_or_unknown` column.

# %%
unique_missing_or_unknown_pattern_strings = feature_summary.missing_or_unknown.unique()

# %%
unique_missing_or_unknown_pattern_strings.shape
# Out:
# (9,)

# %%
unique_missing_or_unknown_pattern_strings
# Out:
# array(['[-1,0]', '[-1,0,9]', '[0]', '[-1]', '[]', '[-1,9]', '[-1,X]',
#        '[XX]', '[-1,XX]'], dtype=object)

# %% [markdown]
# There are 9 unique pattern strings. Note, the patterns can be grouped into the following 3 categories:
#
# - empty
# - letters
# - numbers

# %% [markdown]
# We define a function to convert the pattern strings into a list.

# %% [markdown]
# Note, during debugging, the category 'TITEL_KZ' is found to be encoded as "0.0" and not "0" despite the specification of [-1,0]. We add the `is_int()` function to try to convert a value to an int to handle this edge case.

# %%
def is_int(value):
  try:
    int(value)
    return True
  except ValueError:
    return False

# %%
def process_missing_or_unknown_string(missing_or_unknown_string):
    characters_to_remove = "[]"
    clean_missing_or_unknown_string = missing_or_unknown_string.translate({ord(i): None for i in characters_to_remove})
    parts = clean_missing_or_unknown_string.split(",")
    for i in range(len(parts)):
        if is_int(parts[i]):
            parts[i] = int(parts[i])
    return parts

# %% [markdown]
# We verify the `process_missing_or_unknown_string()` function returns a list for each unique pattern.

# %%
for missing_or_unknown_string in unique_missing_or_unknown_pattern_strings:
    missing_values_list = process_missing_or_unknown_string(missing_or_unknown_string)
    print(missing_values_list)
# Out:
# [-1, 0]
# [-1, 0, 9]
# [0]
# [-1]
# ['']
# [-1, 9]
# [-1, 'X']
# ['XX']
# [-1, 'XX']

# %% [markdown]
# We now define a function to replace the missing values with `np.nan`.

# %%
def replace_missing_values_with_nan(my_features, my_feature_info, log_interval=1):
    for row_index in range(my_features.shape[0]):
        if row_index % log_interval == 0:
            print("row_index: ", row_index)
        for column_index in range(my_features.shape[1]):
            missing_or_unknown_string = my_feature_info.iloc[column_index].missing_or_unknown
            missing_value_list = process_missing_or_unknown_string(missing_or_unknown_string)
            value = my_features.iloc[row_index,column_index]
            for missing_index in range(len(missing_value_list)):
                missing_value = missing_value_list[missing_index]
                if is_int(value) == True:
                    if int(value) == missing_value_list[missing_index]:
                        my_features.iloc[row_index,column_index] = np.nan
                        break;
                else:
                    if value == missing_value_list[missing_index]:
                        my_features.iloc[row_index,column_index] = np.nan
                        break;
    return my_features

# %% [markdown]
# #### Validation of function replace_missing_values_with_nan

# %% [markdown]
# We will test the `replace_missing_values_with_nan()` function with one row representing each category of patterns.

# %% [markdown]
# ##### Category 1 Validation

# %% [markdown]
# Test for category empty representing pattern `'[]'`:

# %%
pattern_empty_columns = feature_summary[feature_summary.missing_or_unknown == "[]"]

# %%
pattern_empty_columns.shape
# Out:
# (10, 4)

# %%
pattern_empty_columns
# Out:
#              attribute information_level         type missing_or_unknown
# 12     GFK_URLAUBERTYP            person  categorical                 []
# 13    GREEN_AVANTGARDE            person  categorical                 []
# 44        ANZ_PERSONEN         household      numeric                 []
# 45           ANZ_TITEL         household      numeric                 []
# 51        ANZ_HH_TITEL          building      numeric                 []
# 53         KONSUMNAEHE          building      ordinal                 []
# 69  GEBAEUDETYP_RASTER        region_rr1      ordinal                 []
# 71          MOBI_REGIO        region_rr1      ordinal                 []
# 72   ONLINE_AFFINITAET        region_rr1      ordinal                 []
# 74    KBA13_ANZAHL_PKW    macrocell_plz8      numeric                 []

# %%
pattern_empty_rows = general_demographics[pd.isnull(general_demographics['GFK_URLAUBERTYP']) == True]

# %%
pattern_empty_rows.shape
# Out:
# (4854, 85)

# %%
pattern_empty_row = pattern_empty_rows[:1]

# %%
pattern_empty_row["GFK_URLAUBERTYP"]
# Out:
# 138   NaN
# Name: GFK_URLAUBERTYP, dtype: float64

# %% [markdown]
# The column GFK_URLAUBERTYP has a value of NaN. We call the `replace_missing_values_with_nan()` function on `pattern_empty_row`.

# %%
replace_missing_values_with_nan(pattern_empty_row, feature_summary)
# Out:
# row_index:  0
# C:\Users\dguev\Anaconda3\lib\site-packages\pandas\core\indexing.py:964: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#      AGER_TYP  ALTERSKATEGORIE_GROB  ANREDE_KZ  CJT_GESAMTTYP  \
# 138       NaN                     3          1            NaN
#
#      FINANZ_MINIMALIST  FINANZ_SPARER  FINANZ_VORSORGER  FINANZ_ANLEGER  \
# 138                  5              3                 4               2
#
#      FINANZ_UNAUFFAELLIGER  FINANZ_HAUSBAUER  ...  PLZ8_ANTG1  PLZ8_ANTG2  \
# 138                      4                 1  ...         NaN         NaN
#
#      PLZ8_ANTG3  PLZ8_ANTG4  PLZ8_BAUMAX  PLZ8_HHZ  PLZ8_GBZ  ARBEIT  \
# 138         NaN         NaN          NaN       NaN       NaN     4.0
#
# ...

# %%
pattern_empty_row["GFK_URLAUBERTYP"]
# Out:
# 138   NaN
# Name: GFK_URLAUBERTYP, dtype: float64

# %% [markdown]
# We can see that the column 'GFK_URLAUBERTYP' now has 'NaN'.

# %% [markdown]
# ##### Category 2 Validation

# %% [markdown]
# Test for category letters representing patterns `[-1,'X']`, `['XX']`, and `[-1,'XX']`:

# %%
pattern_letters_columns = feature_summary[feature_summary.missing_or_unknown == "[XX]"]

# %%
pattern_letters_columns.shape
# Out:
# (1, 4)

# %%
pattern_letters_columns
# Out:
#          attribute information_level         type missing_or_unknown
# 58  CAMEO_DEU_2015     microcell_rr4  categorical               [XX]

# %%
pattern_letters_rows = general_demographics[general_demographics["CAMEO_DEU_2015"] == "XX"]

# %%
pattern_letters_rows.shape
# Out:
# (373, 85)

# %%
pattern_letters_row = pattern_letters_rows[:1]

# %%
pattern_letters_row["CAMEO_DEU_2015"]
# Out:
# 2511    XX
# Name: CAMEO_DEU_2015, dtype: object

# %% [markdown]
# The column 'CAMEO_DEU_2015' has a value of 'XX'. We call the `replace_missing_values_with_nan()` function on `pattern_letters_row`.

# %%
replace_missing_values_with_nan(pattern_letters_row, feature_summary)
# Out:
# row_index:  0
#       AGER_TYP  ALTERSKATEGORIE_GROB  ANREDE_KZ  CJT_GESAMTTYP  \
# 2511       NaN                     2          2            6.0
#
#       FINANZ_MINIMALIST  FINANZ_SPARER  FINANZ_VORSORGER  FINANZ_ANLEGER  \
# 2511                  4              2                 4               3
#
#       FINANZ_UNAUFFAELLIGER  FINANZ_HAUSBAUER  ...  PLZ8_ANTG1  PLZ8_ANTG2  \
# 2511                      3                 1  ...         NaN         NaN
#
#       PLZ8_ANTG3  PLZ8_ANTG4  PLZ8_BAUMAX  PLZ8_HHZ  PLZ8_GBZ  ARBEIT  \
# 2511         NaN         NaN          NaN       NaN       NaN     4.0
#
#       ORTSGR_KLS9  RELAT_AB
# 2511          6.0       5.0
#
# [1 rows x 85 columns]

# %%
pattern_letters_row["CAMEO_DEU_2015"]
# Out:
# 2511    NaN
# Name: CAMEO_DEU_2015, dtype: object

# %% [markdown]
# We can see that the column 'CAMEO_DEU_2015' now has 'NaN'.

# %% [markdown]
# ##### Category 3 Validation

# %% [markdown]
# Test for category numbers representing patterns `'[-1,0]'`, `'[-1,0,9]'`, `'[0]'`, `'[-1]'`, and `'[-1,9]'`:

# %%
pattern_numbers_columns = feature_summary[feature_summary.missing_or_unknown == "[-1,0]"]

# %%
pattern_numbers_columns.shape
# Out:
# (16, 4)

# %%
pattern_numbers_columns
# Out:
#                 attribute information_level         type missing_or_unknown
# 0                AGER_TYP            person  categorical             [-1,0]
# 2               ANREDE_KZ            person  categorical             [-1,0]
# 14             HEALTH_TYP            person      ordinal             [-1,0]
# 21       NATIONALITAET_KZ            person  categorical             [-1,0]
# 22  PRAEGENDE_JUGENDJAHRE            person        mixed             [-1,0]
# 40               TITEL_KZ            person  categorical             [-1,0]
# 46     HH_EINKOMMEN_SCORE         household      ordinal             [-1,0]
# 48         W_KEIT_KIND_HH         household      ordinal             [-1,0]
# 49         WOHNDAUER_2008         household      ordinal             [-1,0]
# 52            GEBAEUDETYP          building  categorical             [-1,0]
# 64           KBA05_BAUMAX     microcell_rr3        mixed             [-1,0]
# ...

# %%
pattern_numbers_rows = general_demographics[general_demographics["AGER_TYP"] == -1]

# %%
pattern_numbers_rows.shape
# Out:
# (677503, 85)

# %%
pattern_numbers_row = pattern_numbers_rows[:1]

# %%
pattern_numbers_row["AGER_TYP"]
# Out:
# 0   -1
# Name: AGER_TYP, dtype: int64

# %% [markdown]
# The column `AGER_TYP` has a value of `-1`. We call the `replace_missing_values_with_nan()` function on `pattern_numbers_row`.

# %%
replace_missing_values_with_nan(pattern_numbers_row, feature_summary)
# Out:
# row_index:  0
#    AGER_TYP  ALTERSKATEGORIE_GROB  ANREDE_KZ  CJT_GESAMTTYP  \
# 0       NaN                     2          1            2.0
#
#    FINANZ_MINIMALIST  FINANZ_SPARER  FINANZ_VORSORGER  FINANZ_ANLEGER  \
# 0                  3              4                 3               5
#
#    FINANZ_UNAUFFAELLIGER  FINANZ_HAUSBAUER  ...  PLZ8_ANTG1  PLZ8_ANTG2  \
# 0                      5                 3  ...         NaN         NaN
#
#    PLZ8_ANTG3  PLZ8_ANTG4  PLZ8_BAUMAX  PLZ8_HHZ  PLZ8_GBZ  ARBEIT  \
# 0         NaN         NaN          NaN       NaN       NaN     NaN
#
#    ORTSGR_KLS9  RELAT_AB
# 0          NaN       NaN
#
# [1 rows x 85 columns]

# %%
pattern_numbers_row["AGER_TYP"]
# Out:
# 0   NaN
# Name: AGER_TYP, dtype: float64

# %% [markdown]
# We can see that the column 'AGER_TYP' now has 'NaN'.

# %% [markdown]
# #### Conversion of All Data

# %% [markdown]
# We now proceed to replacing all the missing values with NaNs. Note, these step can take a long time. It was taking about 9 hours on my local desktop. To avoid having to repeat this step, after processing with the `replace_missing_values_with_nan()` function, the dataset is saved to disk to the `general_demographics_with_nans.csv` file.

# %%
# We time how long it takes to run the 'replace_missing_values_with_nan' function.
# To make sure the function is working, we log a print statement at a specified interval.
log_interval = 20000
start_time = time.time()
replace_missing_values_with_nan(general_demographics, feature_summary, log_interval)
end_time = time.time()
my_seconds = end_time - start_time
my_time_delta = str(datetime.timedelta(seconds=my_seconds))
# Note, on my local desktop, the run time was about 9 hours.
print("replace_missing_values_with_nan time: {}".format(my_time_delta))

# Save the result into a new df as this step takes a long time to run  
general_demographics.to_csv("general_demographics_with_nans.csv", sep=data_delimiter, index=False)
# Out:
# row_index:  0
# row_index:  20000
# row_index:  40000
# row_index:  60000
# row_index:  80000
# row_index:  100000
# row_index:  120000
# row_index:  140000
# row_index:  160000
# row_index:  180000
# row_index:  200000
# row_index:  220000
# row_index:  240000
# row_index:  260000
# row_index:  280000
# row_index:  300000
# row_index:  320000
# row_index:  340000
# row_index:  360000
# row_index:  380000
# row_index:  400000
# row_index:  420000
# row_index:  440000
# row_index:  460000
# row_index:  480000
# row_index:  500000
# row_index:  520000
# row_index:  540000
# row_index:  560000
# row_index:  580000
# row_index:  600000
# row_index:  620000
# row_index:  640000
# row_index:  660000
# row_index:  680000
# row_index:  700000
# row_index:  720000
# row_index:  740000
# row_index:  760000
# row_index:  780000
# row_index:  800000
# row_index:  820000
# row_index:  840000
# row_index:  860000
# row_index:  880000
# replace_missing_values_with_nan time: 7:51:15.226156

# %% [markdown]
# We will start the next section by reading in the `general_demographics_with_nans.csv` file.

# %% [markdown]
# #### Step 1.1.2: Assess Missing Data in Each Column
#
# How much missing data is present in each column? There are a few columns that are outliers in terms of the proportion of values that are missing. You will want to use matplotlib's [`hist()`](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.hist.html) function to visualize the distribution of missing value counts to find these columns. Identify and document these columns. While some of these columns might have justifications for keeping or re-encoding the data, for this project you should just remove them from the dataframe. (Feel free to make remarks about these outlier columns in the discussion, however!)
#
# For the remaining features, are there any patterns in which columns have, or share, missing data?

# %%
# Perform an assessment of how much missing data there is in each column of the
# dataset.
general_demographics_with_nans = pd.read_csv("general_demographics_with_nans.csv", delimiter=data_delimiter)
general_demographics_with_nans.shape
# Out:
# (891221, 85)

# %%
general_demographics_with_nans.iloc[[0]]
# Out:
#    AGER_TYP  ALTERSKATEGORIE_GROB  ANREDE_KZ  CJT_GESAMTTYP  \
# 0       NaN                   2.0          1            2.0
#
#    FINANZ_MINIMALIST  FINANZ_SPARER  FINANZ_VORSORGER  FINANZ_ANLEGER  \
# 0                  3              4                 3               5
#
#    FINANZ_UNAUFFAELLIGER  FINANZ_HAUSBAUER  ...  PLZ8_ANTG1  PLZ8_ANTG2  \
# 0                      5                 3  ...         NaN         NaN
#
#    PLZ8_ANTG3  PLZ8_ANTG4  PLZ8_BAUMAX  PLZ8_HHZ  PLZ8_GBZ  ARBEIT  \
# 0         NaN         NaN          NaN       NaN       NaN     NaN
#
#    ORTSGR_KLS9  RELAT_AB
# 0          NaN       NaN
#
# [1 rows x 85 columns]

# %% [markdown]
# To calculate the number of null records per column, we are using the `isnull()` method combined with the `sum()` method.

# %%
null_data_count_per_column_with_nans = general_demographics_with_nans.isnull().sum().sort_values(ascending=False)

# %% [markdown]
# We do a sanity check on the returned results by checking the `shape` property and previewing the data with the `head()` method.

# %%
null_data_count_per_column_with_nans.shape
# Out:
# (85,)

# %%
null_data_count_per_column_with_nans.head()
# Out:
# TITEL_KZ        889061
# AGER_TYP        685843
# KK_KUNDENTYP    584612
# KBA05_BAUMAX    476524
# GEBURTSJAHR     392318
# dtype: int64

# %% [markdown]
# We calculate the percentage of null data by dividing the `number_of_general_demographics_records` and multiplying by 100. We are rounding to two decimal places.

# %%
null_data_percentage_per_column_with_nans = np.round((null_data_count_per_column_with_nans/number_of_general_demographics_records)*100,2)

# %% [markdown]
# We do a sanity  check on the calculated results by checking the `shape` property and previewing the data with the `head()` method.

# %%
null_data_percentage_per_column_with_nans.shape
# Out:
# (85,)

# %%
null_data_percentage_per_column_with_nans.head()
# Out:
# TITEL_KZ        99.76
# AGER_TYP        76.96
# KK_KUNDENTYP    65.60
# KBA05_BAUMAX    53.47
# GEBURTSJAHR     44.02
# dtype: float64

# %% [markdown]
# We create a dataframe containing the null data count and the null data percentage per column.

# %%
data_dictionary = {"null_data_count": null_data_count_per_column_with_nans, "null_data_percentage" : null_data_percentage_per_column_with_nans }

# %%
null_data_information_per_column_with_nans = pd.DataFrame(data=data_dictionary, index = null_data_count_per_column_with_nans.index)

# %% [markdown]
# We sort the columns by count.

# %%
null_data_information_per_column_with_nans.sort_values(by='null_data_count', ascending=False, inplace=True)

# %% [markdown]
# We show the dataframe below.

# %%
null_data_information_per_column_with_nans[0:20]
# Out:
#                 null_data_count  null_data_percentage
# TITEL_KZ                 889061                 99.76
# AGER_TYP                 685843                 76.96
# KK_KUNDENTYP             584612                 65.60
# KBA05_BAUMAX             476524                 53.47
# GEBURTSJAHR              392318                 44.02
# ALTER_HH                 310267                 34.81
# REGIOTYP                 158064                 17.74
# KKK                      158064                 17.74
# W_KEIT_KIND_HH           147988                 16.61
# KBA05_ANTG3              133324                 14.96
# KBA05_ANTG2              133324                 14.96
# KBA05_ANTG1              133324                 14.96
# KBA05_GBZ                133324                 14.96
# KBA05_ANTG4              133324                 14.96
# MOBI_REGIO               133324                 14.96
# PLZ8_GBZ                 116515                 13.07
# ...

# %%
null_data_information_per_column_with_nans[20:40]
# Out:
#                        null_data_count  null_data_percentage
# PLZ8_ANTG3                      116515                 13.07
# PLZ8_ANTG2                      116515                 13.07
# HEALTH_TYP                      111196                 12.48
# SHOPPER_TYP                     111196                 12.48
# VERS_TYP                        111196                 12.48
# NATIONALITAET_KZ                108315                 12.15
# PRAEGENDE_JUGENDJAHRE           108164                 12.14
# KBA13_ANZAHL_PKW                105800                 11.87
# ANZ_HAUSHALTE_AKTIV              99611                 11.18
# CAMEO_INTL_2015                  99352                 11.15
# CAMEO_DEU_2015                   99352                 11.15
# CAMEO_DEUG_2015                  99352                 11.15
# LP_LEBENSPHASE_FEIN              97632                 10.95
# ARBEIT                           97375                 10.93
# ...

# %%
null_data_information_per_column_with_nans[40:60]
# Out:
#                     null_data_count  null_data_percentage
# BALLRAUM                      93740                 10.52
# GEBAEUDETYP_RASTER            93155                 10.45
# WOHNLAGE                      93148                 10.45
# OST_WEST_KZ                   93148                 10.45
# MIN_GEBAEUDEJAHR              93148                 10.45
# GEBAEUDETYP                   93148                 10.45
# LP_FAMILIE_GROB               77792                  8.73
# LP_FAMILIE_FEIN               77792                  8.73
# KONSUMNAEHE                   73969                  8.30
# ANZ_PERSONEN                  73499                  8.25
# SOHO_KZ                       73499                  8.25
# ANZ_TITEL                     73499                  8.25
# WOHNDAUER_2008                73499                  8.25
# HH_EINKOMMEN_SCORE            18348                  2.06
# LP_STATUS_FEIN                 4854                  0.54
# ...

# %%
null_data_information_per_column_with_nans[60:85]
# Out:
#                        null_data_count  null_data_percentage
# ALTERSKATEGORIE_GROB              2881                  0.32
# SEMIO_MAT                            0                  0.00
# SEMIO_TRADV                          0                  0.00
# SEMIO_PFLICHT                        0                  0.00
# SEMIO_KAEM                           0                  0.00
# SEMIO_DOM                            0                  0.00
# SEMIO_KRIT                           0                  0.00
# SEMIO_RAT                            0                  0.00
# SEMIO_KULT                           0                  0.00
# SEMIO_ERL                            0                  0.00
# SEMIO_LUST                           0                  0.00
# SEMIO_VERT                           0                  0.00
# FINANZ_ANLEGER                       0                  0.00
# SEMIO_REL                            0                  0.00
# ...

# %%
# Investigate patterns in the amount of missing data in each column.

# %% [markdown]
# We make a histogram of the null data information per column using count.

# %%
plt.hist(null_data_information_per_column_with_nans.null_data_count, bins='auto')
plt.xlabel("Count of missing value")
plt.ylabel("Column Counts")
plt.title("Histogram of missing value counts")
plt.grid(True)
plt.show()

# %% [markdown]
# We make a histogram of the null data information per column using percentage.

# %%
plt.hist(null_data_information_per_column_with_nans.null_data_percentage, bins='auto')
plt.xlabel("Percentage of missing value (%)")
plt.ylabel("Column Counts")
plt.title("Histogram of missing value counts")
plt.grid(True)
plt.show()

# %%
# Remove the outlier columns from the dataset. (You'll perform other data
# engineering tasks such as re-encoding and imputation later.)

# %% [markdown]
# We drop all columns that have a null data percentage higher than 30%.

# %%
outlier_columns = null_data_information_per_column_with_nans[null_data_information_per_column_with_nans["null_data_percentage"] > 30.00]

# %% [markdown]
# The following 6 columns will be dropped:

# %%
outlier_columns
# Out:
#               null_data_count  null_data_percentage
# TITEL_KZ               889061                 99.76
# AGER_TYP               685843                 76.96
# KK_KUNDENTYP           584612                 65.60
# KBA05_BAUMAX           476524                 53.47
# GEBURTSJAHR            392318                 44.02
# ALTER_HH               310267                 34.81

# %% [markdown]
# We extract from the dataframe a list of the 6 columns.

# %%
outlier_columns_list = list(outlier_columns.index)

# %%
outlier_columns_list
# Out:
# ['TITEL_KZ',
#  'AGER_TYP',
#  'KK_KUNDENTYP',
#  'KBA05_BAUMAX',
#  'GEBURTSJAHR',
#  'ALTER_HH']

# %% [markdown]
# We drop the columns.

# %%
general_demographics_with_nans.drop(outlier_columns_list, axis="columns", inplace=True)

# %% [markdown]
# As a sanity check, we use shape and head to verify there are now 79 instead of 85 columns.

# %%
general_demographics_with_nans.shape
# Out:
# (891221, 79)

# %%
general_demographics_with_nans.head()
# Out:
#    ALTERSKATEGORIE_GROB  ANREDE_KZ  CJT_GESAMTTYP  FINANZ_MINIMALIST  \
# 0                   2.0          1            2.0                  3
# 1                   1.0          2            5.0                  1
# 2                   3.0          2            3.0                  1
# 3                   4.0          2            2.0                  4
# 4                   3.0          1            5.0                  4
#
#    FINANZ_SPARER  FINANZ_VORSORGER  FINANZ_ANLEGER  FINANZ_UNAUFFAELLIGER  \
# 0              4                 3               5                      5
# 1              5                 2               5                      4
# 2              4                 1               2                      3
# 3              2                 5               2                      1
# 4              3                 4               1                      3
#
#    FINANZ_HAUSBAUER  FINANZTYP  ...  PLZ8_ANTG1  PLZ8_ANTG2  PLZ8_ANTG3  \
# ...

# %% [markdown]
# To facilitate further processing, we create a .csv file with the outlier columns removed.

# %%
# Save the result to a .csv file for further processing.  
general_demographics_with_nans.to_csv("general_demographics_without_outlier_columns.csv", sep=data_delimiter, index=False)

# %% [markdown]
# We need to update the feature summary dataset by removing the outlier columns.

# %%
for index in range(len(outlier_columns_list)):
    indexName = feature_summary[feature_summary["attribute"] == outlier_columns_list[index]]
    print("indexName:",indexName)
    print("dropping column: ", outlier_columns_list[index])
    feature_summary.drop(indexName.index, inplace=True)
# Out:
# indexName:    attribute information_level         type missing_or_unknown
# 40  TITEL_KZ            person  categorical             [-1,0]
# dropping column:  TITEL_KZ
# indexName:   attribute information_level         type missing_or_unknown
# 0  AGER_TYP            person  categorical             [-1,0]
# dropping column:  AGER_TYP
# indexName:        attribute information_level         type missing_or_unknown
# 47  KK_KUNDENTYP         household  categorical               [-1]
# dropping column:  KK_KUNDENTYP
# indexName:        attribute information_level   type missing_or_unknown
# 64  KBA05_BAUMAX     microcell_rr3  mixed             [-1,0]
# dropping column:  KBA05_BAUMAX
# indexName:       attribute information_level     type missing_or_unknown
# 11  GEBURTSJAHR            person  numeric                [0]
# dropping column:  GEBURTSJAHR
# indexName:    attribute information_level      type missing_or_unknown
# 43  ALTER_HH         household  interval                [0]
# ...

# %%
feature_summary.shape
# Out:
# (79, 4)

# %%
feature_summary.head()
# Out:
#               attribute information_level         type missing_or_unknown
# 1  ALTERSKATEGORIE_GROB            person      ordinal           [-1,0,9]
# 2             ANREDE_KZ            person  categorical             [-1,0]
# 3         CJT_GESAMTTYP            person  categorical                [0]
# 4     FINANZ_MINIMALIST            person      ordinal               [-1]
# 5         FINANZ_SPARER            person      ordinal               [-1]

# %% [markdown]
# We save the feature summary dataset without the outlier columns to the file `feature_summary_without_outlier_columns.csv`.

# %%
feature_summary.to_csv("feature_summary_without_outlier_columns.csv", sep=data_delimiter, index=False)

# %% [markdown]
# #### Discussion 1.1.2: Assess Missing Data in Each Column

# %% [markdown]
# By looking at the histogram, we see that some columns have a lot of missing data. At the extreme, the `TITEL_KZ` column is missing data for 99.76% of the data records. The fist major gap of separation in the histogram seems to be between the 20 to 30% bins, so any data above 30% was dropped. This affected the following 6 columns:

# %%
outlier_columns
# Out:
#               null_data_count  null_data_percentage
# TITEL_KZ               889061                 99.76
# AGER_TYP               685843                 76.96
# KK_KUNDENTYP           584612                 65.60
# KBA05_BAUMAX           476524                 53.47
# GEBURTSJAHR            392318                 44.02
# ALTER_HH               310267                 34.81

# %% [markdown]
# These columns have the following descriptions:
#
# | Category | Description |
# |----------|-------------|
# | TITEL_KZ | Academic title flag |
# | AGER_TYP | Best-ager typology  |
# | KK_KUNDENTYP | Consumer pattern over past 12 months |
# | KBA05_BAUMAX | Most common building type within the microcell |
# | GERBURTSJAHR | Year of birth |
# | ALTER_HH | Birthdate of head of household |
#
# Three of the categories (AGER_TYP, GERBURTSJAHR, and ALTER_HH) are related to a person's age. It seems individuals were not comfortable sharing their age.

# %% [markdown]
# #### Step 1.1.3: Assess Missing Data in Each Row
#
# Now, you'll perform a similar assessment for the rows of the dataset. How much data is missing in each row? As with the columns, you should see some groups of points that have a very different numbers of missing values. Divide the data into two subsets: one for data points that are above some threshold for missing values, and a second subset for points below that threshold.
#
# In order to know what to do with the outlier rows, we should see if the distribution of data values on columns that are not missing data (or are missing very little data) are similar or different between the two groups. Select at least five of these columns and compare the distribution of values.
# - You can use seaborn's [`countplot()`](https://seaborn.pydata.org/generated/seaborn.countplot.html) function to create a bar chart of code frequencies and matplotlib's [`subplot()`](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html) function to put bar charts for the two subplots side by side.
# - To reduce repeated code, you might want to write a function that can perform this comparison, taking as one of its arguments a column to be compared.
#
# Depending on what you observe in your comparison, this will have implications on how you approach your conclusions later in the analysis. If the distributions of non-missing features look similar between the data with many missing values and the data with few or no missing values, then we could argue that simply dropping those points from the analysis won't present a major issue. On the other hand, if the data with many missing values looks very different from the data with few or no missing values, then we should make a note on those data as special. We'll revisit these data later on. **Either way, you should continue your analysis for now using just the subset of the data with few or no missing values.**

# %%
# How much data is missing in each row of the dataset?
general_demographics_without_outlier_columns = pd.read_csv("general_demographics_without_outlier_columns.csv", delimiter=data_delimiter)
general_demographics_without_outlier_columns.shape
# Out:
# (891221, 79)

# %%
null_data_count_per_row_with_nans = general_demographics_with_nans.isnull().sum(axis=1).sort_values(ascending=False)

# %% [markdown]
# We do a sanity check on the returned results by checking the `shape` property and previewing the data with the `head()` method.

# %%
null_data_count_per_row_with_nans.shape
# Out:
# (891221,)

# %%
null_data_count_per_row_with_nans.head()
# Out:
# 643174    49
# 732775    49
# 472919    48
# 183108    47
# 139316    47
# dtype: int64

# %% [markdown]
# We calculate the percentage of null data by dividing the `number_of_columns` and multiplying by 100. We are rounding to two decimal places.

# %%
number_of_columns = general_demographics_with_nans.shape[1]
number_of_columns
# Out:
# 79

# %%
null_data_percentage_per_row_with_nans = np.round((null_data_count_per_row_with_nans/number_of_columns)*100,2)

# %%
null_data_percentage_per_row_with_nans.shape
# Out:
# (891221,)

# %%
null_data_percentage_per_row_with_nans.head()
# Out:
# 643174    62.03
# 732775    62.03
# 472919    60.76
# 183108    59.49
# 139316    59.49
# dtype: float64

# %% [markdown]
# We create a dataframe containing the null data count and the null data percentage per row.

# %%
data_dictionary = {"null_data_count": null_data_count_per_row_with_nans, "null_data_percentage" : null_data_percentage_per_row_with_nans }

# %%
null_data_information_per_row_with_nans = pd.DataFrame(data=data_dictionary, index = null_data_count_per_row_with_nans.index)

# %% [markdown]
# We sort the columns by count.

# %%
null_data_information_per_row_with_nans.sort_values(by='null_data_count', ascending=False, inplace=True)

# %% [markdown]
# We preview the dataframe with the `head()` method.

# %%
null_data_information_per_row_with_nans.head()
# Out:
#         null_data_count  null_data_percentage
# 643174               49                 62.03
# 732775               49                 62.03
# 472919               48                 60.76
# 397806               47                 59.49
# 344502               47                 59.49

# %% [markdown]
# We make a histogram of the null data information per row using count.

# %%
plt.hist(null_data_information_per_row_with_nans.null_data_count, bins=20)
plt.xlabel("Count of missing value")
plt.ylabel("Row Counts")
plt.title("Histogram of missing value counts")
plt.grid(True)
plt.show()

# %% [markdown]
# We make a histogram of the null data information per row using percentage.

# %%
plt.hist(null_data_information_per_row_with_nans.null_data_percentage, bins=20)
plt.xlabel("Percentage of missing value (%)")
plt.ylabel("Row Counts")
plt.title("Histogram of missing value counts")
plt.grid(True)
plt.show()

# %%
# Write code to divide the data into two subsets based on the number of missing
# values in each row.
missing_row_percentage_threshold = 30
missing_row_percentage_threshold
# Out:
# 30

# %%
rows_above_threshold = null_data_information_per_row_with_nans[null_data_information_per_row_with_nans["null_data_percentage"] > missing_row_percentage_threshold]

# %%
rows_above_threshold.shape
# Out:
# (93384, 2)

# %%
rows_above_threshold.head()
# Out:
#         null_data_count  null_data_percentage
# 643174               49                 62.03
# 732775               49                 62.03
# 472919               48                 60.76
# 397806               47                 59.49
# 344502               47                 59.49

# %%
rows_above_threshold.tail()
# Out:
#         null_data_count  null_data_percentage
# 692272               24                 30.38
# 716869               24                 30.38
# 767147               24                 30.38
# 775017               24                 30.38
# 704938               24                 30.38

# %%
general_demographics_without_outlier_rows = general_demographics_without_outlier_columns.drop(rows_above_threshold.index)

# %%
general_demographics_without_outlier_rows.shape
# Out:
# (797837, 79)

# %%
general_demographics_without_outlier_rows.head()
# Out:
#    ALTERSKATEGORIE_GROB  ANREDE_KZ  CJT_GESAMTTYP  FINANZ_MINIMALIST  \
# 1                   1.0          2            5.0                  1
# 2                   3.0          2            3.0                  1
# 3                   4.0          2            2.0                  4
# 4                   3.0          1            5.0                  4
# 5                   1.0          2            2.0                  3
#
#    FINANZ_SPARER  FINANZ_VORSORGER  FINANZ_ANLEGER  FINANZ_UNAUFFAELLIGER  \
# 1              5                 2               5                      4
# 2              4                 1               2                      3
# 3              2                 5               2                      1
# 4              3                 4               1                      3
# 5              1                 5               2                      2
#
#    FINANZ_HAUSBAUER  FINANZTYP  ...  PLZ8_ANTG1  PLZ8_ANTG2  PLZ8_ANTG3  \
# ...

# %%
rows_below_threshold = null_data_information_per_row_with_nans[null_data_information_per_row_with_nans["null_data_percentage"] <= missing_row_percentage_threshold]

# %%
rows_below_threshold.shape
# Out:
# (797837, 2)

# %%
rows_below_threshold.head()
# Out:
#         null_data_count  null_data_percentage
# 174408               23                 29.11
# 605871               23                 29.11
# 365948               23                 29.11
# 380549               23                 29.11
# 770310               23                 29.11

# %%
rows_below_threshold.tail()
# Out:
#         null_data_count  null_data_percentage
# 133834                0                   0.0
# 268850                0                   0.0
# 268832                0                   0.0
# 268849                0                   0.0
# 445610                0                   0.0

# %%
general_demographics_outlier_rows = general_demographics_without_outlier_columns.drop(rows_below_threshold.index)

# %%
general_demographics_outlier_rows.shape
# Out:
# (93384, 79)

# %%
general_demographics_outlier_rows.head()
# Out:
#     ALTERSKATEGORIE_GROB  ANREDE_KZ  CJT_GESAMTTYP  FINANZ_MINIMALIST  \
# 0                    2.0          1            2.0                  3
# 11                   2.0          1            6.0                  3
# 14                   3.0          1            6.0                  3
# 17                   2.0          1            6.0                  3
# 24                   3.0          2            6.0                  3
#
#     FINANZ_SPARER  FINANZ_VORSORGER  FINANZ_ANLEGER  FINANZ_UNAUFFAELLIGER  \
# 0               4                 3               5                      5
# 11              4                 3               5                      5
# 14              4                 3               5                      5
# 17              4                 3               5                      5
# 24              4                 3               5                      5
#
#     FINANZ_HAUSBAUER  FINANZTYP  ...  PLZ8_ANTG1  PLZ8_ANTG2  PLZ8_ANTG3  \
# ...

# %%
# Compare the distribution of values for at least five columns where there are
# no or few missing values, between the two subsets.
def compare_distributions(distribution_1, distribution_2, column_name):
    ax1 = plt.subplot(1,2,1)
    sns.countplot(distribution_1[column_name], ax=ax1)
    ax2 = plt.subplot(1,2,2)
    sns.countplot(distribution_2[column_name], ax=ax2)

# %% [markdown]
# ALTERSKATEGORIE_GROB is the estimated age based on given name analysis.

# %%
compare_distributions(general_demographics_without_outlier_rows, general_demographics_outlier_rows, 'ALTERSKATEGORIE_GROB')

# %% [markdown]
# ANREDE_KZ is gender.

# %%
compare_distributions(general_demographics_without_outlier_rows, general_demographics_outlier_rows, 'ANREDE_KZ')

# %% [markdown]
# FINANZTYP is most descriptive financial type for individual.

# %%
compare_distributions(general_demographics_without_outlier_rows, general_demographics_outlier_rows, 'FINANZTYP')

# %% [markdown]
# GFK_URLAUBERTYP is vacation habits.

# %%
compare_distributions(general_demographics_without_outlier_rows, general_demographics_outlier_rows, 'GFK_URLAUBERTYP')

# %% [markdown]
# LP_LEBENSPHASE_FEIN is life stage, fine scale.

# %%
compare_distributions(general_demographics_without_outlier_rows, general_demographics_outlier_rows, 'LP_LEBENSPHASE_FEIN')

# %% [markdown]
# We save the `general_population_data_without_outlier_rows` dataset as it will be used for further analysis.

# %%
general_demographics_without_outlier_rows.shape
# Out:
# (797837, 79)

# %%
general_demographics_without_outlier_rows.to_csv("general_demographics_without_outlier_rows.csv", sep=data_delimiter, index=False)

# %% [markdown]
# We also save the `general_demographics_outlier_rows` dataset in case we want to do further analysis later on.

# %%
general_demographics_outlier_rows.shape
# Out:
# (93384, 79)

# %%
general_demographics_outlier_rows.to_csv("general_demographics_outlier_rows.csv", sep=data_delimiter, index=False)

# %% [markdown]
# #### Discussion 1.1.3: Assess Missing Data in Each Row

# %% [markdown]
# The distribution of values between the dataset with low missing values that will be kept for further analysis and the dataset with high missing values that will be removed was compared for 5 columns.
#
# The distribution of values was the same between the following three categories:
#
# - ALTERSKATEGORIE_GROB - Estimated age based on given name analysis
# - ANREDE_KZ - Gender
# - LP_LEBENSPHASE_FEIN - Life stage, fine scale
#
# The distribution of values was not the same between the following two categories:
#
# - FINANZTYP - Most descriptive financial type for individual
# - GFK_URLAUBERTYP - Vacation habits
#
# In the two distributions that don't match, one value seems to have a large number that skews the distribution.

# %% [markdown]
# ### Step 1.2: Select and Re-Encode Features
#
# Checking for missing data isn't the only way in which you can prepare a dataset for analysis. Since the unsupervised learning techniques to be used will only work on data that is encoded numerically, you need to make a few encoding changes or additional assumptions to be able to make progress. In addition, while almost all of the values in the dataset are encoded using numbers, not all of them represent numeric values. Check the third column of the feature summary (`feature_summary`) for a summary of types of measurement.
# - For numeric and interval data, these features can be kept without changes.
# - Most of the variables in the dataset are ordinal in nature. While ordinal values may technically be non-linear in spacing, make the simplifying assumption that the ordinal variables can be treated as being interval in nature (that is, kept without any changes).
# - Special handling may be necessary for the remaining two variable types: categorical, and 'mixed'.
#
# In the first two parts of this sub-step, you will perform an investigation of the categorical and mixed-type features and make a decision on each of them, whether you will keep, drop, or re-encode each. Then, in the last part, you will create a new data frame with only the selected and engineered columns.
#
# Data wrangling is often the trickiest part of the data analysis process, and there's a lot of it to be done here. But stick with it: once you're done with this step, you'll be ready to get to the machine learning parts of the project!

# %%
# How many features are there of each data type?

# %% [markdown]
# We read in the feature summary data without the outlier columns.

# %%
feature_summary_without_outlier_columns = pd.read_csv("feature_summary_without_outlier_columns.csv", delimiter=data_delimiter)

# %%
feature_summary_without_outlier_columns.shape
# Out:
# (79, 4)

# %%
feature_summary_without_outlier_columns.head()
# Out:
#               attribute information_level         type missing_or_unknown
# 0  ALTERSKATEGORIE_GROB            person      ordinal           [-1,0,9]
# 1             ANREDE_KZ            person  categorical             [-1,0]
# 2         CJT_GESAMTTYP            person  categorical                [0]
# 3     FINANZ_MINIMALIST            person      ordinal               [-1]
# 4         FINANZ_SPARER            person      ordinal               [-1]

# %% [markdown]
# Using the `groupby()` method, we can now answer the question 'How many features are there of each data type?'.

# %%
feature_summary_without_outlier_columns.groupby(by="type").count()
# Out:
#              attribute  information_level  missing_or_unknown
# type
# categorical         18                 18                  18
# mixed                6                  6                   6
# numeric              6                  6                   6
# ordinal             49                 49                  49

# %% [markdown]
# We will leave the 6 numeric and 49 ordinal types as is. We will focus on the 18 categorical and 6 mixed types.

# %% [markdown]
# Below, we filter out the categorical features.

# %%
categorical_features = feature_summary_without_outlier_columns[feature_summary_without_outlier_columns['type'] == "categorical"]

# %%
categorical_features.shape
# Out:
# (18, 4)

# %%
categorical_features
# Out:
#            attribute information_level         type missing_or_unknown
# 1          ANREDE_KZ            person  categorical             [-1,0]
# 2      CJT_GESAMTTYP            person  categorical                [0]
# 9          FINANZTYP            person  categorical               [-1]
# 10   GFK_URLAUBERTYP            person  categorical                 []
# 11  GREEN_AVANTGARDE            person  categorical                 []
# 15   LP_FAMILIE_FEIN            person  categorical                [0]
# 16   LP_FAMILIE_GROB            person  categorical                [0]
# 17    LP_STATUS_FEIN            person  categorical                [0]
# 18    LP_STATUS_GROB            person  categorical                [0]
# 19  NATIONALITAET_KZ            person  categorical             [-1,0]
# 36       SHOPPER_TYP            person  categorical               [-1]
# 37           SOHO_KZ            person  categorical               [-1]
# ...

# %% [markdown]
# We filter out the mixed features.

# %%
mixed_features = feature_summary_without_outlier_columns[feature_summary_without_outlier_columns['type'] == "mixed"]

# %%
mixed_features.shape
# Out:
# (6, 4)

# %%
mixed_features
# Out:
#                 attribute information_level   type missing_or_unknown
# 13    LP_LEBENSPHASE_FEIN            person  mixed                [0]
# 14    LP_LEBENSPHASE_GROB            person  mixed                [0]
# 20  PRAEGENDE_JUGENDJAHRE            person  mixed             [-1,0]
# 51               WOHNLAGE          building  mixed               [-1]
# 54        CAMEO_INTL_2015     microcell_rr4  mixed            [-1,XX]
# 73            PLZ8_BAUMAX    macrocell_plz8  mixed             [-1,0]

# %% [markdown]
# #### Step 1.2.1: Re-Encode Categorical Features
#
# For categorical data, you would ordinarily need to encode the levels as dummy variables. Depending on the number of categories, perform one of the following:
# - For binary (two-level) categoricals that take numeric values, you can keep them without needing to do anything.
# - There is one binary variable that takes on non-numeric values. For this one, you need to re-encode the values as numbers or create a dummy variable.
# - For multi-level categoricals (three or more values), you can choose to encode the values using multiple dummy variables (e.g. via [OneHotEncoder](http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OneHotEncoder.html)), or (to keep things straightforward) just drop them from the analysis. As always, document your choices in the Discussion section.

# %%
# Assess categorical variables: 
# - which are binary? 
# - which are multi-level?
# - which one needs to be re-encoded?

# %% [markdown]
# We start our analysis of categorial variables by reading in the file `general_demographics_without_outlier_rows.csv`.

# %%
general_demographics_without_outlier_rows = pd.read_csv("general_demographics_without_outlier_rows.csv", delimiter=data_delimiter)

# %%
general_demographics_without_outlier_rows.shape
# Out:
# (797837, 79)

# %%
general_demographics_without_outlier_rows.head()
# Out:
#    ALTERSKATEGORIE_GROB  ANREDE_KZ  CJT_GESAMTTYP  FINANZ_MINIMALIST  \
# 0                   1.0          2            5.0                  1
# 1                   3.0          2            3.0                  1
# 2                   4.0          2            2.0                  4
# 3                   3.0          1            5.0                  4
# 4                   1.0          2            2.0                  3
#
#    FINANZ_SPARER  FINANZ_VORSORGER  FINANZ_ANLEGER  FINANZ_UNAUFFAELLIGER  \
# 0              5                 2               5                      4
# 1              4                 1               2                      3
# 2              2                 5               2                      1
# 3              3                 4               1                      3
# 4              1                 5               2                      2
#
#    FINANZ_HAUSBAUER  FINANZTYP  ...  PLZ8_ANTG1  PLZ8_ANTG2  PLZ8_ANTG3  \
# ...

# %% [markdown]
# Using the `nunique()` method, we will try to determine if the categories are binary or multilevel.

# %%
features_with_unique_values = pd.DataFrame()

# %%
for feature in categorical_features.attribute:
    unique_values = general_demographics_without_outlier_rows[feature].nunique()
    print(feature, unique_values)
    new_df = pd.DataFrame({'feature': [feature], 'unique_values': [unique_values]})
    #print(new_df)
    features_with_unique_values = features_with_unique_values.append(new_df,ignore_index=True)
    #print(features_with_unique_values.shape)
# Out:
# ANREDE_KZ 2
# CJT_GESAMTTYP 6
# FINANZTYP 6
# GFK_URLAUBERTYP 12
# GREEN_AVANTGARDE 2
# LP_FAMILIE_FEIN 11
# LP_FAMILIE_GROB 5
# LP_STATUS_FEIN 10
# LP_STATUS_GROB 5
# NATIONALITAET_KZ 3
# SHOPPER_TYP 4
# SOHO_KZ 2
# VERS_TYP 2
# ZABEOTYP 6
# GEBAEUDETYP 7
# OST_WEST_KZ 2
# CAMEO_DEUG_2015 9
# CAMEO_DEU_2015 44

# %%
features_with_unique_values.shape
# Out:
# (18, 2)

# %%
features_with_unique_values.head()
# Out:
#             feature  unique_values
# 0         ANREDE_KZ              2
# 1     CJT_GESAMTTYP              6
# 2         FINANZTYP              6
# 3   GFK_URLAUBERTYP             12
# 4  GREEN_AVANTGARDE              2

# %% [markdown]
# From the `features_with_unique_values` dataframe, we extract the multivariable categories.

# %%
multivariable_categories = features_with_unique_values[features_with_unique_values["unique_values"] > 2]

# %%
multivariable_categories.shape
# Out:
# (13, 2)

# %%
multivariable_categories
# Out:
#              feature  unique_values
# 1      CJT_GESAMTTYP              6
# 2          FINANZTYP              6
# 3    GFK_URLAUBERTYP             12
# 5    LP_FAMILIE_FEIN             11
# 6    LP_FAMILIE_GROB              5
# 7     LP_STATUS_FEIN             10
# 8     LP_STATUS_GROB              5
# 9   NATIONALITAET_KZ              3
# 10       SHOPPER_TYP              4
# 13          ZABEOTYP              6
# 14       GEBAEUDETYP              7
# 16   CAMEO_DEUG_2015              9
# 17    CAMEO_DEU_2015             44

# %% [markdown]
# From the `features_with_unique_values` dataframe, we extract the binary categories.

# %%
binary_categories = features_with_unique_values[features_with_unique_values["unique_values"] == 2]

# %%
binary_categories.shape
# Out:
# (5, 2)

# %%
binary_categories
# Out:
#              feature  unique_values
# 0          ANREDE_KZ              2
# 4   GREEN_AVANTGARDE              2
# 11           SOHO_KZ              2
# 12          VERS_TYP              2
# 15       OST_WEST_KZ              2

# %% [markdown]
# For the binary categories, we use the `unique()` method to print out all the unique values in order to determine if they need to be encoded.

# %%
for feature in binary_categories.feature:
    feature_unique_values = general_demographics_without_outlier_rows[feature].unique()
    print(feature, feature_unique_values)
# Out:
# ANREDE_KZ [2 1]
# GREEN_AVANTGARDE [0 1]
# SOHO_KZ [1. 0.]
# VERS_TYP [ 2.  1. nan]
# OST_WEST_KZ ['W' 'O']

# %% [markdown]
# The column `OST_WEST_KZ` is the only binary feature that needs to be encoded.

# %% [markdown]
# For simplicity, any multivariable feature will be dropped.

# %%
multivariable_categories_list = list(multivariable_categories.feature)

# %%
multivariable_categories_list
# Out:
# ['CJT_GESAMTTYP',
#  'FINANZTYP',
#  'GFK_URLAUBERTYP',
#  'LP_FAMILIE_FEIN',
#  'LP_FAMILIE_GROB',
#  'LP_STATUS_FEIN',
#  'LP_STATUS_GROB',
#  'NATIONALITAET_KZ',
#  'SHOPPER_TYP',
#  'ZABEOTYP',
#  'GEBAEUDETYP',
#  'CAMEO_DEUG_2015',
#  'CAMEO_DEU_2015']

# %%
general_demographics_without_outlier_rows.shape
# Out:
# (797837, 79)

# %%
general_demographics_without_outlier_rows.drop(multivariable_categories_list, axis="columns", inplace=True)

# %%
general_demographics_without_outlier_rows.shape
# Out:
# (797837, 66)

# %% [markdown]
# We write out the general demographics dataset without multivariable categories.

# %%
general_demographics_without_outlier_rows.to_csv("general_demographics_without_multivariable_categories.csv", sep=data_delimiter, index=False)

# %% [markdown]
# We remove the multivariable categories from the feature summary dataset.

# %%
multivariable_categories_list
# Out:
# ['CJT_GESAMTTYP',
#  'FINANZTYP',
#  'GFK_URLAUBERTYP',
#  'LP_FAMILIE_FEIN',
#  'LP_FAMILIE_GROB',
#  'LP_STATUS_FEIN',
#  'LP_STATUS_GROB',
#  'NATIONALITAET_KZ',
#  'SHOPPER_TYP',
#  'ZABEOTYP',
#  'GEBAEUDETYP',
#  'CAMEO_DEUG_2015',
#  'CAMEO_DEU_2015']

# %%
for index in range(len(multivariable_categories_list)):
    indexName = feature_summary_without_outlier_columns[feature_summary_without_outlier_columns["attribute"] == multivariable_categories_list[index]]
    print("indexName:", indexName)
    print("dropping column: ", multivariable_categories_list[index])
    feature_summary_without_outlier_columns.drop(indexName.index, inplace=True)
# Out:
# indexName:        attribute information_level         type missing_or_unknown
# 2  CJT_GESAMTTYP            person  categorical                [0]
# dropping column:  CJT_GESAMTTYP
# indexName:    attribute information_level         type missing_or_unknown
# 9  FINANZTYP            person  categorical               [-1]
# dropping column:  FINANZTYP
# indexName:           attribute information_level         type missing_or_unknown
# 10  GFK_URLAUBERTYP            person  categorical                 []
# dropping column:  GFK_URLAUBERTYP
# indexName:           attribute information_level         type missing_or_unknown
# 15  LP_FAMILIE_FEIN            person  categorical                [0]
# dropping column:  LP_FAMILIE_FEIN
# indexName:           attribute information_level         type missing_or_unknown
# 16  LP_FAMILIE_GROB            person  categorical                [0]
# dropping column:  LP_FAMILIE_GROB
# ...

# %%
feature_summary_without_outlier_columns.shape
# Out:
# (66, 4)

# %% [markdown]
# We write out the feature summary dataset without the multivariable categories.

# %%
feature_summary_without_outlier_columns.to_csv("feature_summary_without_multivariable_categories.csv", sep=data_delimiter, index=False)

# %% [markdown]
# We read in the feature summary dataset without multivariable categories.

# %%
feature_summary_without_multivariable_categories = pd.read_csv("feature_summary_without_multivariable_categories.csv", delimiter=data_delimiter)

# %%
feature_summary_without_multivariable_categories.shape
# Out:
# (66, 4)

# %%
feature_summary_without_multivariable_categories.head()
# Out:
#               attribute information_level         type missing_or_unknown
# 0  ALTERSKATEGORIE_GROB            person      ordinal           [-1,0,9]
# 1             ANREDE_KZ            person  categorical             [-1,0]
# 2     FINANZ_MINIMALIST            person      ordinal               [-1]
# 3         FINANZ_SPARER            person      ordinal               [-1]
# 4      FINANZ_VORSORGER            person      ordinal               [-1]

# %% [markdown]
# We read in the general demographics dataset without the multivariable categories in order to do further analaysis.

# %%
# Re-encode categorical variable(s) to be kept in the analysis.
general_demographics_without_multivariable_categories = pd.read_csv("general_demographics_without_multivariable_categories.csv", delimiter=data_delimiter)

# %%
general_demographics_without_multivariable_categories.shape
# Out:
# (797837, 66)

# %%
general_demographics_without_multivariable_categories.columns
# Out:
# Index(['ALTERSKATEGORIE_GROB', 'ANREDE_KZ', 'FINANZ_MINIMALIST',
#        'FINANZ_SPARER', 'FINANZ_VORSORGER', 'FINANZ_ANLEGER',
#        'FINANZ_UNAUFFAELLIGER', 'FINANZ_HAUSBAUER', 'GREEN_AVANTGARDE',
#        'HEALTH_TYP', 'LP_LEBENSPHASE_FEIN', 'LP_LEBENSPHASE_GROB',
#        'PRAEGENDE_JUGENDJAHRE', 'RETOURTYP_BK_S', 'SEMIO_SOZ', 'SEMIO_FAM',
#        'SEMIO_REL', 'SEMIO_MAT', 'SEMIO_VERT', 'SEMIO_LUST', 'SEMIO_ERL',
#        'SEMIO_KULT', 'SEMIO_RAT', 'SEMIO_KRIT', 'SEMIO_DOM', 'SEMIO_KAEM',
#        'SEMIO_PFLICHT', 'SEMIO_TRADV', 'SOHO_KZ', 'VERS_TYP', 'ANZ_PERSONEN',
#        'ANZ_TITEL', 'HH_EINKOMMEN_SCORE', 'W_KEIT_KIND_HH', 'WOHNDAUER_2008',
#        'ANZ_HAUSHALTE_AKTIV', 'ANZ_HH_TITEL', 'KONSUMNAEHE',
#        'MIN_GEBAEUDEJAHR', 'OST_WEST_KZ', 'WOHNLAGE', 'CAMEO_INTL_2015',
#        'KBA05_ANTG1', 'KBA05_ANTG2', 'KBA05_ANTG3', 'KBA05_ANTG4', 'KBA05_GBZ',
#        'BALLRAUM', 'EWDICHTE', 'INNENSTADT', 'GEBAEUDETYP_RASTER', 'KKK',
# ...

# %% [markdown]
# We use the `get_dummies()` method to encode the column `OST_WEST_KZ`.

# %%
general_demographics_with_binary_categories_encoded = pd.get_dummies(general_demographics_without_multivariable_categories, columns=['OST_WEST_KZ'])

# %%
general_demographics_with_binary_categories_encoded.shape
# Out:
# (797837, 67)

# %%
general_demographics_with_binary_categories_encoded.columns
# Out:
# Index(['ALTERSKATEGORIE_GROB', 'ANREDE_KZ', 'FINANZ_MINIMALIST',
#        'FINANZ_SPARER', 'FINANZ_VORSORGER', 'FINANZ_ANLEGER',
#        'FINANZ_UNAUFFAELLIGER', 'FINANZ_HAUSBAUER', 'GREEN_AVANTGARDE',
#        'HEALTH_TYP', 'LP_LEBENSPHASE_FEIN', 'LP_LEBENSPHASE_GROB',
#        'PRAEGENDE_JUGENDJAHRE', 'RETOURTYP_BK_S', 'SEMIO_SOZ', 'SEMIO_FAM',
#        'SEMIO_REL', 'SEMIO_MAT', 'SEMIO_VERT', 'SEMIO_LUST', 'SEMIO_ERL',
#        'SEMIO_KULT', 'SEMIO_RAT', 'SEMIO_KRIT', 'SEMIO_DOM', 'SEMIO_KAEM',
#        'SEMIO_PFLICHT', 'SEMIO_TRADV', 'SOHO_KZ', 'VERS_TYP', 'ANZ_PERSONEN',
#        'ANZ_TITEL', 'HH_EINKOMMEN_SCORE', 'W_KEIT_KIND_HH', 'WOHNDAUER_2008',
#        'ANZ_HAUSHALTE_AKTIV', 'ANZ_HH_TITEL', 'KONSUMNAEHE',
#        'MIN_GEBAEUDEJAHR', 'WOHNLAGE', 'CAMEO_INTL_2015', 'KBA05_ANTG1',
#        'KBA05_ANTG2', 'KBA05_ANTG3', 'KBA05_ANTG4', 'KBA05_GBZ', 'BALLRAUM',
#        'EWDICHTE', 'INNENSTADT', 'GEBAEUDETYP_RASTER', 'KKK', 'MOBI_REGIO',
# ...

# %% [markdown]
# The column `OST_WEST_KZ` has been one-hot encoded to the columns `OST_WEST_KZ_O` and `OST_WEST_KZ_W`.

# %% [markdown]
# We save the general demographics dataset with the binary categories encoded.

# %%
general_demographics_with_binary_categories_encoded.to_csv("general_demographics_with_binary_categories_encoded.csv", sep=data_delimiter, index=False)

# %% [markdown]
# We update the feature summary dataset by dropping `OST_WEST_KZ` and adding the one-hot encoding columns for `OST_WEST_KZ_O` and `OST_WEST_KZ_W`.

# %%
one_hot_encoding_to_drop_list = ['OST_WEST_KZ']

# %%
for index in range(len(one_hot_encoding_to_drop_list)):
    indexName = feature_summary_without_multivariable_categories[feature_summary_without_multivariable_categories["attribute"] == one_hot_encoding_to_drop_list[index]]
    print("indexName:", indexName)
    print("dropping column: ", one_hot_encoding_to_drop_list[index])
    feature_summary_without_multivariable_categories.drop(indexName.index, inplace=True)
# Out:
# indexName:       attribute information_level         type missing_or_unknown
# 39  OST_WEST_KZ          building  categorical               [-1]
# dropping column:  OST_WEST_KZ

# %%
feature_summary_without_multivariable_categories.head()
# Out:
#               attribute information_level         type missing_or_unknown
# 0  ALTERSKATEGORIE_GROB            person      ordinal           [-1,0,9]
# 1             ANREDE_KZ            person  categorical             [-1,0]
# 2     FINANZ_MINIMALIST            person      ordinal               [-1]
# 3         FINANZ_SPARER            person      ordinal               [-1]
# 4      FINANZ_VORSORGER            person      ordinal               [-1]

# %%
one_hot_encoding_column_1 = {"attribute": ['OST_WEST_KZ_O'], "information_level" : ["building"], "type": ['one_hot_encoded'], "missing_or_unknown": ['[nan]']}

# %%
one_hot_encoding_column_1
# Out:
# {'attribute': ['OST_WEST_KZ_O'],
#  'information_level': ['building'],
#  'type': ['one_hot_encoded'],
#  'missing_or_unknown': ['[nan]']}

# %%
df_one_hot_encoding_column_1 = pd.DataFrame(one_hot_encoding_column_1)

# %%
df_one_hot_encoding_column_1
# Out:
#        attribute information_level             type missing_or_unknown
# 0  OST_WEST_KZ_O          building  one_hot_encoded              [nan]

# %%
one_hot_encoding_column_2 = {"attribute": ['OST_WEST_KZ_W'], "information_level" : ["building"], "type": ['one_hot_encoded'], "missing_or_unknown": ['[nan]']}

# %%
one_hot_encoding_column_2
# Out:
# {'attribute': ['OST_WEST_KZ_W'],
#  'information_level': ['building'],
#  'type': ['one_hot_encoded'],
#  'missing_or_unknown': ['[nan]']}

# %%
df_one_hot_encoding_column_2 = pd.DataFrame(one_hot_encoding_column_2)

# %%
df_one_hot_encoding_column_2
# Out:
#        attribute information_level             type missing_or_unknown
# 0  OST_WEST_KZ_W          building  one_hot_encoded              [nan]

# %% [markdown]
# We append new entries for the one hot encoded columns to the feature summary dataset.

# %%
feature_summary_with_binary_categories_encoded = feature_summary_without_multivariable_categories.append(df_one_hot_encoding_column_1, ignore_index=True)
feature_summary_with_binary_categories_encoded = feature_summary_with_binary_categories_encoded.append(df_one_hot_encoding_column_2, ignore_index=True)

# %%
feature_summary_with_binary_categories_encoded.shape
# Out:
# (67, 4)

# %%
feature_summary_with_binary_categories_encoded.tail()
# Out:
#         attribute information_level             type missing_or_unknown
# 62         ARBEIT         community          ordinal             [-1,9]
# 63    ORTSGR_KLS9         community          ordinal             [-1,0]
# 64       RELAT_AB         community          ordinal             [-1,9]
# 65  OST_WEST_KZ_O          building  one_hot_encoded              [nan]
# 66  OST_WEST_KZ_W          building  one_hot_encoded              [nan]

# %% [markdown]
# We save the feature summary dataset with the binary categories encoded.

# %%
feature_summary_with_binary_categories_encoded.to_csv("feature_summary_with_binary_categories_encoded.csv", sep=data_delimiter, index=False)

# %% [markdown]
# #### Discussion 1.2.1: Re-Encode Categorical Features

# %% [markdown]
# The 18 categorical features were divided into binary and multivariable subsets as follows:

# %%
binary_categories.shape
# Out:
# (5, 2)

# %%
binary_categories
# Out:
#              feature  unique_values
# 0          ANREDE_KZ              2
# 4   GREEN_AVANTGARDE              2
# 11           SOHO_KZ              2
# 12          VERS_TYP              2
# 15       OST_WEST_KZ              2

# %%
multivariable_categories.shape
# Out:
# (13, 2)

# %%
multivariable_categories
# Out:
#              feature  unique_values
# 1      CJT_GESAMTTYP              6
# 2          FINANZTYP              6
# 3    GFK_URLAUBERTYP             12
# 5    LP_FAMILIE_FEIN             11
# 6    LP_FAMILIE_GROB              5
# 7     LP_STATUS_FEIN             10
# 8     LP_STATUS_GROB              5
# 9   NATIONALITAET_KZ              3
# 10       SHOPPER_TYP              4
# 13          ZABEOTYP              6
# 14       GEBAEUDETYP              7
# 16   CAMEO_DEUG_2015              9
# 17    CAMEO_DEU_2015             44

# %% [markdown]
# To simplify analysis due to the large number of features that would be created with one hot encoding, multivariable categories where dropped. The binary categories were kept. Since 4 out of the 5 binary categories were represented with numerical values, no further processing was done on these 4 categories. The `OST_WEST_KZ` category was one hot encoded into `OST_WEST_KZ_O` and `OST_WEST_KZ_W`.

# %% [markdown]
# #### Step 1.2.2: Engineer Mixed-Type Features
#
# There are a handful of features that are marked as "mixed" in the feature summary that require special treatment in order to be included in the analysis. There are two in particular that deserve attention; the handling of the rest are up to your own choices:
# - "PRAEGENDE_JUGENDJAHRE" combines information on three dimensions: generation by decade, movement (mainstream vs. avantgarde), and nation (east vs. west). While there aren't enough levels to disentangle east from west, you should create two new variables to capture the other two dimensions: an interval-type variable for decade, and a binary variable for movement.
# - "CAMEO_INTL_2015" combines information on two axes: wealth and life stage. Break up the two-digit codes by their 'tens'-place and 'ones'-place digits into two new ordinal variables (which, for the purposes of this project, is equivalent to just treating them as their raw numeric values).
# - If you decide to keep or engineer new features around the other mixed-type features, make sure you note your steps in the Discussion section.
#
# Be sure to check `Data_Dictionary.md` for the details needed to finish these tasks.

# %% [markdown]
# We read in the general demographics dataset with the binary categories encoded.

# %%
general_demographics_with_binary_categories_encoded = pd.read_csv("general_demographics_with_binary_categories_encoded.csv", delimiter=data_delimiter)

# %%
general_demographics_with_binary_categories_encoded.shape
# Out:
# (797837, 67)

# %%
general_demographics_with_binary_categories_encoded.head()
# Out:
#    ALTERSKATEGORIE_GROB  ANREDE_KZ  FINANZ_MINIMALIST  FINANZ_SPARER  \
# 0                   1.0          2                  1              5
# 1                   3.0          2                  1              4
# 2                   4.0          2                  4              2
# 3                   3.0          1                  4              3
# 4                   1.0          2                  3              1
#
#    FINANZ_VORSORGER  FINANZ_ANLEGER  FINANZ_UNAUFFAELLIGER  FINANZ_HAUSBAUER  \
# 0                 2               5                      4                 5
# 1                 1               2                      3                 5
# 2                 5               2                      1                 2
# 3                 4               1                      3                 2
# 4                 5               2                      2                 5
#
#    GREEN_AVANTGARDE  HEALTH_TYP  ...  PLZ8_ANTG3  PLZ8_ANTG4  PLZ8_BAUMAX  \
# ...

# %%
# Investigate "PRAEGENDE_JUGENDJAHRE" and engineer two new variables.

# %% [markdown]
# In `Data_Dictionary.md`, `PRAEGENDE_JUGENJAHRE` is the dominating movement of a person's youth. Per the guidance given above, we will separate the `PRAEGENDE_JUGENJAHRE` variable into an interval-type variable for decade and a binary variable for movement.

# %%
general_demographics_with_binary_categories_encoded['PRAEGENDE_JUGENDJAHRE'].unique()
# Out:
# array([14., 15.,  8.,  3., 10., 11.,  5.,  9.,  6.,  4., nan,  2.,  1.,
#        12., 13.,  7.])

# %% [markdown]
# To improve code readability, we are using an enumeration called Decades. We define a `get_decade()` method to do the mapping from the original variable into the new decade variable.

# %%
class Decades(enum.Enum):
    Forties = 1
    Fifties = 2
    Sixties = 3
    Seventies = 4
    Eighties = 5
    Nineties = 6
    
def get_decade(value):
    forties_group = [1, 2]
    fifties_group = [3, 4]
    sixties_group = [5, 6, 7]
    seventies_group = [8, 9]
    eighties_group = [10, 11, 12, 13]
    nineties_group = [14, 15]
    if value in forties_group:
        return Decades.Forties.value # 40s
    elif value in fifties_group:
        return Decades.Fifties.value # 50s
    elif value in sixties_group:
        return Decades.Sixties.value # 60s
    elif value in seventies_group:
        return Decades.Seventies.value # 70s
    elif value in eighties_group:
        return Decades.Eighties.value # 80s
    elif value in nineties_group:
        return Decades.Nineties.value # 90s
    else:
        return np.nan

# %% [markdown]
# To improve code readability, we are using an enumeration called Movements. We define a `get_movement()` method to do the mapping from the original variable to into the new movement variable.

# %%
class Movements(enum.Enum):
    Avantgarde = 0
    Mainstream = 1
    
def get_movement(value):
    avantgarde_group = [2, 4, 6, 7, 9, 11, 13, 15]
    mainstream_group = [1, 3, 5, 8, 10, 12, 14]
    if value in avantgarde_group:
        return Movements.Avantgarde.value
    elif value in mainstream_group:
        return Movements.Mainstream.value
    else: 
        return np.nan

# %% [markdown]
# We use the `apply()` method of the dataframe to apply a function to each row. This will use the current value as the argument to the function. We save the mapped value to a new column. We call the columns `PRAEGENDE_JUGENDJAHRE_DECADE` and `PRAEGENDE_JUGENDJAHRE_MOVEMENT`.

# %%
# Create decade column
general_demographics_with_binary_categories_encoded['PRAEGENDE_JUGENDJAHRE_DECADE'] = general_demographics_with_binary_categories_encoded['PRAEGENDE_JUGENDJAHRE'].apply(get_decade)

# Create movement column
general_demographics_with_binary_categories_encoded['PRAEGENDE_JUGENDJAHRE_MOVEMENT'] = general_demographics_with_binary_categories_encoded['PRAEGENDE_JUGENDJAHRE'].apply(get_movement)

# %%
general_demographics_with_binary_categories_encoded.shape
# Out:
# (797837, 69)

# %% [markdown]
# We drop the original `PRAEGENDE_JUGENDJAHRE` column.

# %%
# We need to drop orignal PRAEGENDE_JUGENDJAHRE column
general_demographics_with_binary_categories_encoded.drop('PRAEGENDE_JUGENDJAHRE', axis='columns', inplace=True)

# %%
general_demographics_with_binary_categories_encoded.shape
# Out:
# (797837, 68)

# %% [markdown]
# In Data_Dictionary.md, `CAMEO_INTL_2015` is the wealth and life stage typolog mapped to an international code. Per the guidance given above, we will separate the `CAMEO_INTL_2015` variable into two new ordinal variables using the ones and tenths place as the divider.

# %%
general_demographics_with_binary_categories_encoded['CAMEO_INTL_2015'].head()
# Out:
# 0    51.0
# 1    24.0
# 2    12.0
# 3    43.0
# 4    54.0
# Name: CAMEO_INTL_2015, dtype: float64

# %%
# Investigate "CAMEO_INTL_2015" and engineer two new variables.
general_demographics_with_binary_categories_encoded['CAMEO_INTL_2015'].unique()
# Out:
# array([51., 24., 12., 43., 54., 22., 14., 13., 15., 33., 41., 34., 55.,
#        nan, 25., 23., 31., 52., 35., 45., 44., 32.])

# %% [markdown]
# To improve code readability, we are using a `HouseholdWealth` enumeration. We define a `get_weatlh()` function to do the mapping. When the two-digit code is treated as a string, the first character represents the tens place.

# %%
# Note, by treating the two-digit codes as a string, we can break up 
# the two-digit code into the 'tens'-place and 'ones'-place digits and 
# create two new ordinal variables. The first digit is wealth. The 
# second digit is life stage.
class HouseholdWealth(enum.Enum):
    Wealthy = 1
    Prosperous = 2
    Comfortable = 3
    LessAffluent = 4
    Poorer = 5
    
def get_wealth(value):
    if pd.isnull(value):
        return np.nan
    else:
        try:
            # Process the first digit.
            intValue = int(str(value)[0])
            if intValue == HouseholdWealth.Wealthy.value:
                return HouseholdWealth.Wealthy.value
            elif intValue == HouseholdWealth.Prosperous.value:
                return HouseholdWealth.Prosperous.value
            elif intValue == HouseholdWealth.Comfortable.value:
                return HouseholdWealth.Comfortable.value
            elif intValue == HouseholdWealth.LessAffluent.value:
                return HouseholdWealth.LessAffluent.value
            elif intValue == HouseholdWealth.Poorer.value:
                return HouseholdWealth.Poorer.value
            else:
                # Handle values outside the valid range.
                return np.nan
        except ValueError:
            return np.nan

# %% [markdown]
# We verify the `get_wealth()` function is working by testing it out on some test values below. Note, the two-digit code is being stored as an float in the data.

# %%
get_wealth(15.0)
# Out:
# 1

# %%
get_wealth(51.0)
# Out:
# 5

# %%
get_wealth('XX')
# Out:
# nan

# %%
get_wealth(61.0)
# Out:
# nan

# %% [markdown]
# To improve code readability, we are using a `LifeStage` enumeration. We define a `get_lifestage()` function to do the mapping. When the two-digit code is treated as a string, the second character represents the ones place.

# %%
class LifeStage(enum.Enum):
    PreFamily = 1
    YoungCouples = 2
    Families = 3
    OlderFamilies = 4
    Elders = 5
    
def get_lifestage(value):
    if pd.isnull(value):
        return np.nan
    else:
        try:
            # Process the second digit.
            intValue = int(str(value)[1])
            if intValue == LifeStage.PreFamily.value:
                return LifeStage.PreFamily.value
            elif intValue == LifeStage.YoungCouples.value:
                return LifeStage.YoungCouples.value
            elif intValue == LifeStage.Families.value:
                return LifeStage.Families.value
            elif intValue == LifeStage.OlderFamilies.value:
                return LifeStage.OlderFamilies.value
            elif intValue == LifeStage.Elders.value:
                return LifeStage.Elders.value
            else:
                # Handle values outside the valid range.
                return np.nan
        except ValueError:
            return np.nan

# %% [markdown]
# We verify the `get_lifestage()` function is working by testing it out on some test values below. Note, the two-digit code is being stored as an float in the data.

# %%
get_lifestage(15.0)
# Out:
# 5

# %%
get_lifestage(51.0)
# Out:
# 1

# %%
get_lifestage('XX')
# Out:
# nan

# %%
get_lifestage(16.0)
# Out:
# nan

# %% [markdown]
# We use the `apply()` method of the dataframe to apply a function to each row. This will use the current value as the argument to the function. We save the mapped value to a new column. We call the columns `CAMEO_INTL_2015_WEATLH` and `CAMEO_INTL_2015_LIFESTAGE`.

# %%
# Create wealth column
general_demographics_with_binary_categories_encoded['CAMEO_INTL_2015_WEALTH'] = general_demographics_with_binary_categories_encoded['CAMEO_INTL_2015'].apply(get_wealth)

# %%
general_demographics_with_binary_categories_encoded['CAMEO_INTL_2015_WEALTH'].unique()
# Out:
# array([ 5.,  2.,  1.,  4.,  3., nan])

# %%
# Create movement column
general_demographics_with_binary_categories_encoded['CAMEO_INTL_2015_LIFESTAGE'] = general_demographics_with_binary_categories_encoded['CAMEO_INTL_2015'].apply(get_lifestage)

# %%
general_demographics_with_binary_categories_encoded['CAMEO_INTL_2015_LIFESTAGE'].unique()
# Out:
# array([ 1.,  4.,  2.,  3.,  5., nan])

# %%
general_demographics_with_binary_categories_encoded.shape
# Out:
# (797837, 70)

# %% [markdown]
# We drop the orignal `CAMEO_INTL_2015` column.

# %%
# We need to drop orignal CAMEO_INTL_2015 column
general_demographics_with_binary_categories_encoded.drop('CAMEO_INTL_2015', axis='columns', inplace=True)

# %%
general_demographics_with_binary_categories_encoded.shape
# Out:
# (797837, 69)

# %%
general_demographics_with_binary_categories_encoded.columns
# Out:
# Index(['ALTERSKATEGORIE_GROB', 'ANREDE_KZ', 'FINANZ_MINIMALIST',
#        'FINANZ_SPARER', 'FINANZ_VORSORGER', 'FINANZ_ANLEGER',
#        'FINANZ_UNAUFFAELLIGER', 'FINANZ_HAUSBAUER', 'GREEN_AVANTGARDE',
#        'HEALTH_TYP', 'LP_LEBENSPHASE_FEIN', 'LP_LEBENSPHASE_GROB',
#        'RETOURTYP_BK_S', 'SEMIO_SOZ', 'SEMIO_FAM', 'SEMIO_REL', 'SEMIO_MAT',
#        'SEMIO_VERT', 'SEMIO_LUST', 'SEMIO_ERL', 'SEMIO_KULT', 'SEMIO_RAT',
#        'SEMIO_KRIT', 'SEMIO_DOM', 'SEMIO_KAEM', 'SEMIO_PFLICHT', 'SEMIO_TRADV',
#        'SOHO_KZ', 'VERS_TYP', 'ANZ_PERSONEN', 'ANZ_TITEL',
#        'HH_EINKOMMEN_SCORE', 'W_KEIT_KIND_HH', 'WOHNDAUER_2008',
#        'ANZ_HAUSHALTE_AKTIV', 'ANZ_HH_TITEL', 'KONSUMNAEHE',
#        'MIN_GEBAEUDEJAHR', 'WOHNLAGE', 'KBA05_ANTG1', 'KBA05_ANTG2',
#        'KBA05_ANTG3', 'KBA05_ANTG4', 'KBA05_GBZ', 'BALLRAUM', 'EWDICHTE',
#        'INNENSTADT', 'GEBAEUDETYP_RASTER', 'KKK', 'MOBI_REGIO',
#        'ONLINE_AFFINITAET', 'REGIOTYP', 'KBA13_ANZAHL_PKW', 'PLZ8_ANTG1',
# ...

# %% [markdown]
# To simplify analysis, we are going to drop all other mixed type columns.

# %% [markdown]
# We begin by updating the feature summary dataset.

# %%
feature_summary_with_binary_categories_encoded = pd.read_csv("feature_summary_with_binary_categories_encoded.csv", delimiter=data_delimiter)

# %%
feature_summary_with_binary_categories_encoded.shape
# Out:
# (67, 4)

# %% [markdown]
# We drop the original `PRAEGENDE_JUGENDJAHRE` and `CAMEO_INTL_2015` columns.

# %%
drop_mixed_columns_manually_encoded = ['PRAEGENDE_JUGENDJAHRE', 'CAMEO_INTL_2015']

# %%
def drop_rows_by_column(my_dataframe, my_drop_list, drop_column):
    for index in range(len(my_drop_list)):
        row = my_dataframe[my_dataframe[drop_column] == my_drop_list[index]]
        print("row:", row)
        print("dropping feature: ", my_drop_list[index])
        my_dataframe.drop(row.index, inplace=True)

# %%
drop_rows_by_column(feature_summary_with_binary_categories_encoded, drop_mixed_columns_manually_encoded, "attribute")
# Out:
# row:                 attribute information_level   type missing_or_unknown
# 12  PRAEGENDE_JUGENDJAHRE            person  mixed             [-1,0]
# dropping feature:  PRAEGENDE_JUGENDJAHRE
# row:           attribute information_level   type missing_or_unknown
# 40  CAMEO_INTL_2015     microcell_rr4  mixed            [-1,XX]
# dropping feature:  CAMEO_INTL_2015

# %%
feature_summary_with_binary_categories_encoded.shape
# Out:
# (65, 4)

# %% [markdown]
# We add the columns manually created.

# %%
new_decade_column = {"attribute": ['PRAEGENDE_JUGENDJAHRE_DECADE'], "information_level" : ["decade"], "type": ['ordinal'], "missing_or_unknown": ['[nan]']}

# %%
df_new_decade_column = pd.DataFrame(new_decade_column)

# %%
feature_summary_with_binary_categories_encoded = feature_summary_with_binary_categories_encoded.append(df_new_decade_column, ignore_index=True)

# %%
feature_summary_with_binary_categories_encoded.shape
# Out:
# (66, 4)

# %%
new_movement_column = {"attribute": ['PRAEGENDE_JUGENDJAHRE_MOVEMENT'], "information_level" : ["movement"], "type": ['ordinal'], "missing_or_unknown": ['[nan]']}

# %%
df_new_movement_column = pd.DataFrame(new_movement_column)

# %%
feature_summary_with_binary_categories_encoded = feature_summary_with_binary_categories_encoded.append(df_new_movement_column, ignore_index=True)

# %%
feature_summary_with_binary_categories_encoded.shape
# Out:
# (67, 4)

# %%
new_wealth_column = {"attribute": ['CAMEO_INTL_2015_WEALTH'], "information_level" : ["wealth"], "type": ['ordinal'], "missing_or_unknown": ['[nan]']}

# %%
df_new_wealth_column = pd.DataFrame(new_wealth_column)

# %%
feature_summary_with_binary_categories_encoded = feature_summary_with_binary_categories_encoded.append(df_new_wealth_column, ignore_index=True)

# %%
feature_summary_with_binary_categories_encoded.shape
# Out:
# (68, 4)

# %%
new_lifestage_column = {"attribute": ['CAMEO_INTL_2015_LIFESTAGE'], "information_level" : ["lifestage"], "type": ['ordinal'], "missing_or_unknown": ['[nan]']}

# %%
df_new_lifestage_column = pd.DataFrame(new_lifestage_column)

# %%
feature_summary_with_binary_categories_encoded = feature_summary_with_binary_categories_encoded.append(df_new_lifestage_column, ignore_index=True)

# %%
feature_summary_with_binary_categories_encoded.shape
# Out:
# (69, 4)

# %% [markdown]
# With the feature summary dataset updated, we now find a list of the remaining mixed columns.

# %%
remaining_mixed_columns = feature_summary_with_binary_categories_encoded[feature_summary_with_binary_categories_encoded['type'] == "mixed"]

# %%
remaining_mixed_columns
# Out:
#               attribute information_level   type missing_or_unknown
# 10  LP_LEBENSPHASE_FEIN            person  mixed                [0]
# 11  LP_LEBENSPHASE_GROB            person  mixed                [0]
# 38             WOHNLAGE          building  mixed               [-1]
# 57          PLZ8_BAUMAX    macrocell_plz8  mixed             [-1,0]

# %% [markdown]
# To simplify the analysis, we are going to drop the remaining mixed type columns.

# %%
remaining_mixed_columns_list = list(remaining_mixed_columns.attribute)

# %%
remaining_mixed_columns_list
# Out:
# ['LP_LEBENSPHASE_FEIN', 'LP_LEBENSPHASE_GROB', 'WOHNLAGE', 'PLZ8_BAUMAX']

# %% [markdown]
# We drop these rows from the information dataset.

# %%
drop_rows_by_column(feature_summary_with_binary_categories_encoded, remaining_mixed_columns_list, "attribute")
# Out:
# row:               attribute information_level   type missing_or_unknown
# 10  LP_LEBENSPHASE_FEIN            person  mixed                [0]
# dropping feature:  LP_LEBENSPHASE_FEIN
# row:               attribute information_level   type missing_or_unknown
# 11  LP_LEBENSPHASE_GROB            person  mixed                [0]
# dropping feature:  LP_LEBENSPHASE_GROB
# row:    attribute information_level   type missing_or_unknown
# 38  WOHNLAGE          building  mixed               [-1]
# dropping feature:  WOHNLAGE
# row:       attribute information_level   type missing_or_unknown
# 57  PLZ8_BAUMAX    macrocell_plz8  mixed             [-1,0]
# dropping feature:  PLZ8_BAUMAX

# %%
feature_summary_with_binary_categories_encoded.shape
# Out:
# (65, 4)

# %% [markdown]
# We also drop the columns from the general demographics dataset.

# %%
general_demographics_with_binary_categories_encoded.drop(remaining_mixed_columns_list, axis="columns", inplace=True)

# %%
general_demographics_with_binary_categories_encoded.shape
# Out:
# (797837, 65)

# %% [markdown]
# We save the updated general population dataset.

# %%
general_demographics_with_binary_categories_encoded.to_csv("general_demographics_without_mixed_type_columns.csv", sep=data_delimiter, index=False)

# %% [markdown]
# We save the updated feature information dataset.

# %%
feature_summary_with_binary_categories_encoded.to_csv("feature_summary_without_mixed_type_columns.csv", sep=data_delimiter, index=False)

# %% [markdown]
# #### Discussion 1.2.2: Engineer Mixed-Type Features

# %% [markdown]
# The dataset contained the following 6 mixed-type features:
#
# - CAMEO_INTL_2015 - Wealth / Life Stage Typology, mapped to international code
# - LP_LEBENSPHASE_FEIN - Life stage, fine scale
# - LP_LEBENSPHASE_GROB - Life stage, rough scale
# - PLZ8_BAUMAX - Most common building type within the PLZ8 region
# - PRAEGENDE_JUGENDJAHRE - Dominating movement of person's youth (avantgarde vs. mainstream; east vs. west)
# - WOHNLAGE - Neighborhood quality (or rural flag)

# %% [markdown]
# The feature PRAEGENDE_JUGENDJAHRE was separated into two ordinal columns called PRAEGENDE_JUGENDJAHRE_DECADE and PRAEGENDE_JUGENDJAHRE_MOVEMENT.

# %% [markdown]
# The feature CAMEO_INTL_2015 was separated into two ordinal columns called CAMEO_INTL_2015_WEALTH and CAMEO_INTL_2015_LIFESTAGE.

# %% [markdown]
# Since two of the remaining mixed type categories were related to life stage and the other two lacked enough information to decided how best to separate them, it was decided to just drop the remaining mixed type columns to simplify further analysis. We are still left with 65 features.

# %% [markdown]
# #### Step 1.2.3: Complete Feature Selection
#
# In order to finish this step up, you need to make sure that your data frame now only has the columns that you want to keep. To summarize, the dataframe should consist of the following:
# - All numeric, interval, and ordinal type columns from the original dataset.
# - Binary categorical features (all numerically-encoded).
# - Engineered features from other multi-level categorical features and mixed features.
#
# Make sure that for any new columns that you have engineered, that you've excluded the original columns from the final dataset. Otherwise, their values will interfere with the analysis later on the project. For example, you should not keep "PRAEGENDE_JUGENDJAHRE", since its values won't be useful for the algorithm: only the values derived from it in the engineered features you created should be retained. As a reminder, your data should only be from **the subset with few or no missing values**.

# %%
# If there are other re-engineering tasks you need to perform, make sure you
# take care of them here. (Dealing with missing data will come in step 2.1.)

# %% [markdown]
# We do some final sanity checks on the general demographics dataset.

# %%
general_demographics_without_mixed_type_columns = pd.read_csv("general_demographics_without_mixed_type_columns.csv", delimiter=data_delimiter)

# %% [markdown]
# The size should be 65 columns.

# %%
general_demographics_without_mixed_type_columns.shape
# Out:
# (797837, 65)

# %% [markdown]
# We check that the re-engineered columns `CAMEO_INT_2015` and `PRAGENDED_JUGENDJAHRE` have been removed.

# %%
general_demographics_without_mixed_type_columns.columns
# Out:
# Index(['ALTERSKATEGORIE_GROB', 'ANREDE_KZ', 'FINANZ_MINIMALIST',
#        'FINANZ_SPARER', 'FINANZ_VORSORGER', 'FINANZ_ANLEGER',
#        'FINANZ_UNAUFFAELLIGER', 'FINANZ_HAUSBAUER', 'GREEN_AVANTGARDE',
#        'HEALTH_TYP', 'RETOURTYP_BK_S', 'SEMIO_SOZ', 'SEMIO_FAM', 'SEMIO_REL',
#        'SEMIO_MAT', 'SEMIO_VERT', 'SEMIO_LUST', 'SEMIO_ERL', 'SEMIO_KULT',
#        'SEMIO_RAT', 'SEMIO_KRIT', 'SEMIO_DOM', 'SEMIO_KAEM', 'SEMIO_PFLICHT',
#        'SEMIO_TRADV', 'SOHO_KZ', 'VERS_TYP', 'ANZ_PERSONEN', 'ANZ_TITEL',
#        'HH_EINKOMMEN_SCORE', 'W_KEIT_KIND_HH', 'WOHNDAUER_2008',
#        'ANZ_HAUSHALTE_AKTIV', 'ANZ_HH_TITEL', 'KONSUMNAEHE',
#        'MIN_GEBAEUDEJAHR', 'KBA05_ANTG1', 'KBA05_ANTG2', 'KBA05_ANTG3',
#        'KBA05_ANTG4', 'KBA05_GBZ', 'BALLRAUM', 'EWDICHTE', 'INNENSTADT',
#        'GEBAEUDETYP_RASTER', 'KKK', 'MOBI_REGIO', 'ONLINE_AFFINITAET',
#        'REGIOTYP', 'KBA13_ANZAHL_PKW', 'PLZ8_ANTG1', 'PLZ8_ANTG2',
# ...

# %% [markdown]
# Finally, we check that every column is a number.

# %%
np.unique(general_demographics_without_mixed_type_columns.dtypes.values)
# Out:
# array([dtype('int64'), dtype('float64')], dtype=object)

# %% [markdown]
# Every column is either an int64 or float64.

# %%
# Do whatever you need to in order to ensure that the dataframe only contains
# the columns that should be passed to the algorithm functions.

# %% [markdown]
# To keep track of all the column changes, we have been updating the feature information dataset. Let's do a sanity check that the columns in that dataset match up with the general demographics dataset.

# %%
feature_summary_without_mixed_type_columns = pd.read_csv("feature_summary_without_mixed_type_columns.csv", delimiter=data_delimiter)

# %% [markdown]
# We expect the number of columns to be 65.

# %%
feature_summary_without_mixed_type_columns.shape
# Out:
# (65, 4)

# %% [markdown]
# We exepect the number of null data per column to be below the threshold of 30%.

# %%
null_row_threshold = int(general_demographics_without_mixed_type_columns.shape[0]*0.30)

# %%
null_row_threshold
# Out:
# 239351

# %%
for feature in feature_summary_without_mixed_type_columns.attribute:
    null_rows = general_demographics_without_mixed_type_columns[feature].isnull().sum()
    is_below_threshold = null_rows < null_row_threshold
    print("feature: ", feature, "null_rows: ", null_rows, "is_below_threshold:", is_below_threshold)
# Out:
# feature:  ALTERSKATEGORIE_GROB null_rows:  2800 is_below_threshold: True
# feature:  ANREDE_KZ null_rows:  0 is_below_threshold: True
# feature:  FINANZ_MINIMALIST null_rows:  0 is_below_threshold: True
# feature:  FINANZ_SPARER null_rows:  0 is_below_threshold: True
# feature:  FINANZ_VORSORGER null_rows:  0 is_below_threshold: True
# feature:  FINANZ_ANLEGER null_rows:  0 is_below_threshold: True
# feature:  FINANZ_UNAUFFAELLIGER null_rows:  0 is_below_threshold: True
# feature:  FINANZ_HAUSBAUER null_rows:  0 is_below_threshold: True
# feature:  GREEN_AVANTGARDE null_rows:  0 is_below_threshold: True
# feature:  HEALTH_TYP null_rows:  36644 is_below_threshold: True
# feature:  RETOURTYP_BK_S null_rows:  4666 is_below_threshold: True
# feature:  SEMIO_SOZ null_rows:  0 is_below_threshold: True
# feature:  SEMIO_FAM null_rows:  0 is_below_threshold: True
# feature:  SEMIO_REL null_rows:  0 is_below_threshold: True
# feature:  SEMIO_MAT null_rows:  0 is_below_threshold: True
# ...

# %% [markdown]
# We do a final sanity check on the columns we re-engineered by looking at the unqiue values in the columns.

# %%
general_demographics_without_mixed_type_columns['CAMEO_INTL_2015_LIFESTAGE'].unique()
# Out:
# array([ 1.,  4.,  2.,  3.,  5., nan])

# %%
general_demographics_without_mixed_type_columns['CAMEO_INTL_2015_WEALTH'].unique()
# Out:
# array([ 5.,  2.,  1.,  4.,  3., nan])

# %%
general_demographics_without_mixed_type_columns['PRAEGENDE_JUGENDJAHRE_DECADE'].unique()
# Out:
# array([ 6.,  4.,  2.,  5.,  3., nan,  1.])

# %%
general_demographics_without_mixed_type_columns['PRAEGENDE_JUGENDJAHRE_MOVEMENT'].unique()
# Out:
# array([ 1.,  0., nan])

# %% [markdown]
# ### Step 1.3: Create a Cleaning Function
#
# Even though you've finished cleaning up the general population demographics data, it's important to look ahead to the future and realize that you'll need to perform the same cleaning steps on the customer demographics data. In this substep, complete the function below to execute the main feature selection, encoding, and re-engineering steps you performed above. Then, when it comes to looking at the customer data in Step 3, you can just run this function on that DataFrame to get the trimmed dataset in a single step.

# %% [markdown]
# We are going to use knowledge of our prior analysis on the general demographics dataset to inform the `clean_data()` function for the customer dataset. Specifically, we know what columns we would like to drop. We construct a list of columns to drop using this knowledge.
#
# Note, there are subtleties to this approach that lead to different rows being selected, so we will run the `clean_data()` function on both general demographics and customer demographics datasets. Additionally, there is an assumption that the customer demographics dataset is inherently cleaner than the general demographics dataset. Otherwise, if the customer demographics dataset is dirtier, or has more missing data, the column analysis would lead us to drop more columns from the customer demographics dataset. It would be difficult to compare both datasets if they are based on different features. By keeping the threshold of missing data low, we reduce the affect that missing data has on the final results. We will be imputing missing data later in the analysis.

# %%
features_to_drop = [{'feature':'TITEL_KZ', 'drop_reason':'Too Much Missing Data'}, 
                    {'feature':'AGER_TYP', 'drop_reason':'Too Much Missing Data'},
                    {'feature':'KK_KUNDENTYP', 'drop_reason':'Too Much Missing Data'},
                    {'feature':'KBA05_BAUMAX', 'drop_reason':'Too Much Missing Data'},
                    {'feature':'GEBURTSJAHR', 'drop_reason':'Too Much Missing Data'},
                    {'feature':'ALTER_HH', 'drop_reason':'Too Much Missing Data'},
                    {'feature':'CJT_GESAMTTYP', 'drop_reason':'Multivariable Feature'},
                    {'feature':'FINANZTYP', 'drop_reason':'Multivariable Feature'},
                    {'feature':'GFK_URLAUBERTYP', 'drop_reason':'Multivariable Feature'},
                    {'feature':'LP_FAMILIE_FEIN', 'drop_reason':'Multivariable Feature'},
                    {'feature':'LP_FAMILIE_GROB', 'drop_reason':'Multivariable Feature'},
                    {'feature':'LP_STATUS_FEIN', 'drop_reason':'Multivariable Feature'},
                    {'feature':'LP_STATUS_GROB', 'drop_reason':'Multivariable Feature'},
                    {'feature':'NATIONALITAET_KZ', 'drop_reason':'Multivariable Feature'},
                    {'feature':'SHOPPER_TYP', 'drop_reason':'Multivariable Feature'},
                    {'feature':'ZABEOTYP', 'drop_reason':'Multivariable Feature'},
                    {'feature':'GEBAEUDETYP', 'drop_reason':'Multivariable Feature'},
                    {'feature':'CAMEO_DEUG_2015', 'drop_reason':'Multivariable Feature'},
                    {'feature':'CAMEO_DEU_2015', 'drop_reason':'Multivariable Feature'},
                    {'feature':'LP_LEBENSPHASE_FEIN', 'drop_reason':'Mixed Type Feature'},
                    {'feature':'LP_LEBENSPHASE_GROB', 'drop_reason':'Mixed Type Feature'},
                    {'feature':'PLZ8_BAUMAX', 'drop_reason':'Mixed Type Feature'},
                    {'feature':'WOHNLAGE', 'drop_reason':'Mixed Type Feature'}
                    ]

# %%
df_features_to_drop = pd.DataFrame(features_to_drop)

# %%
df_features_to_drop.shape
# Out:
# (23, 2)

# %%
df_features_to_drop
# Out:
#                 feature            drop_reason
# 0              TITEL_KZ  Too Much Missing Data
# 1              AGER_TYP  Too Much Missing Data
# 2          KK_KUNDENTYP  Too Much Missing Data
# 3          KBA05_BAUMAX  Too Much Missing Data
# 4           GEBURTSJAHR  Too Much Missing Data
# 5              ALTER_HH  Too Much Missing Data
# 6         CJT_GESAMTTYP  Multivariable Feature
# 7             FINANZTYP  Multivariable Feature
# 8       GFK_URLAUBERTYP  Multivariable Feature
# 9       LP_FAMILIE_FEIN  Multivariable Feature
# 10      LP_FAMILIE_GROB  Multivariable Feature
# 11       LP_STATUS_FEIN  Multivariable Feature
# 12       LP_STATUS_GROB  Multivariable Feature
# 13     NATIONALITAET_KZ  Multivariable Feature
# 14          SHOPPER_TYP  Multivariable Feature
# 15             ZABEOTYP  Multivariable Feature
# 16          GEBAEUDETYP  Multivariable Feature
# 17      CAMEO_DEUG_2015  Multivariable Feature
# 18       CAMEO_DEU_2015  Multivariable Feature
# ...

# %%
df_features_to_drop.feature
# Out:
# 0                TITEL_KZ
# 1                AGER_TYP
# 2            KK_KUNDENTYP
# 3            KBA05_BAUMAX
# 4             GEBURTSJAHR
# 5                ALTER_HH
# 6           CJT_GESAMTTYP
# 7               FINANZTYP
# 8         GFK_URLAUBERTYP
# 9         LP_FAMILIE_FEIN
# 10        LP_FAMILIE_GROB
# 11         LP_STATUS_FEIN
# 12         LP_STATUS_GROB
# 13       NATIONALITAET_KZ
# 14            SHOPPER_TYP
# 15               ZABEOTYP
# 16            GEBAEUDETYP
# 17        CAMEO_DEUG_2015
# 18         CAMEO_DEU_2015
# 19    LP_LEBENSPHASE_FEIN
# 20    LP_LEBENSPHASE_GROB
# 21            PLZ8_BAUMAX
# 22               WOHNLAGE
# Name: feature, dtype: object

# %%
features_to_drop_list = list(df_features_to_drop.feature)

# %%
features_to_drop_list
# Out:
# ['TITEL_KZ',
#  'AGER_TYP',
#  'KK_KUNDENTYP',
#  'KBA05_BAUMAX',
#  'GEBURTSJAHR',
#  'ALTER_HH',
#  'CJT_GESAMTTYP',
#  'FINANZTYP',
#  'GFK_URLAUBERTYP',
#  'LP_FAMILIE_FEIN',
#  'LP_FAMILIE_GROB',
#  'LP_STATUS_FEIN',
#  'LP_STATUS_GROB',
#  'NATIONALITAET_KZ',
#  'SHOPPER_TYP',
#  'ZABEOTYP',
#  'GEBAEUDETYP',
#  'CAMEO_DEUG_2015',
#  'CAMEO_DEU_2015',
#  'LP_LEBENSPHASE_FEIN',
#  'LP_LEBENSPHASE_GROB',
#  'PLZ8_BAUMAX',
#  'WOHNLAGE']

# %% [markdown]
# Using the prior analysis, we define a `clean_data` function that will be used for both general demographics and customer demographics datasets.

# %%
def clean_data(my_data_name, my_dataframe, my_feature_summary, my_data_delimiter, my_prior_knowledge_features_to_drop, my_missing_fields_threshold, my_log_interval):
    """
    Perform feature trimming, re-encoding, and engineering for demographics
    data
    
    INPUT: Demographics DataFrame
    OUTPUT: Trimmed and cleaned demographics DataFrame
    """
    
    # Put in code here to execute all main cleaning steps:
    
    # 1.) Convert missing value codes into NaNs, ...
    start_time = time.time()
    clean_dataframe = replace_missing_values_with_nan(my_dataframe, my_feature_summary, my_log_interval)
    end_time = time.time()
    my_seconds = end_time - start_time
    my_time_delta = str(datetime.timedelta(seconds=my_seconds))
    print("replace_missing_values_with_nan time: {}".format(my_time_delta))
    
    # Save the result into a new df as this step takes a long time to run
    time_stamp = time.strftime("%Y%m%d_%H%M%S")
    tmp_file = my_data_name + "_demographics_with_nans_" + time_stamp + ".csv"
    clean_dataframe.to_csv(tmp_file, sep=my_data_delimiter, index=False)
    clean_dataframe = pd.read_csv(tmp_file, delimiter=my_data_delimiter)
    
    # 2.) Remove selected columns and rows, ...
    # 2.1) Apply missing fields threshold to rows.
    clean_dataframe = clean_dataframe.drop(clean_dataframe[clean_dataframe.isnull().sum(axis='columns') > my_missing_fields_threshold].index)
    # 2.2) Remove features (i.e. columns) based on prior analysis.
    clean_dataframe = clean_dataframe.drop(my_prior_knowledge_features_to_drop, axis='columns')
        
    # 3.) select, re-encode, and engineer column values. 
    clean_dataframe = pd.get_dummies(clean_dataframe, columns=['OST_WEST_KZ'])
    
    clean_dataframe['PRAEGENDE_JUGENDJAHRE_DECADE'] = clean_dataframe['PRAEGENDE_JUGENDJAHRE'].apply(get_decade)
    clean_dataframe['PRAEGENDE_JUGENDJAHRE_MOVEMENT'] = clean_dataframe['PRAEGENDE_JUGENDJAHRE'].apply(get_movement)
    clean_dataframe.drop('PRAEGENDE_JUGENDJAHRE', axis='columns', inplace=True)
    
    clean_dataframe['CAMEO_INTL_2015_WEALTH'] = clean_dataframe['CAMEO_INTL_2015'].apply(get_wealth)
    clean_dataframe['CAMEO_INTL_2015_LIFESTAGE'] = clean_dataframe['CAMEO_INTL_2015'].apply(get_lifestage)
    clean_dataframe.drop('CAMEO_INTL_2015', axis='columns', inplace=True)
    
    # Return the cleaned dataframe.
    return clean_dataframe

# %%
# Shared data delimiter.
data_delimiter = ";"
missing_fields_threshold = 25
log_interval = 20000

# Load in the feature summary data.
feature_summary_file = "AZDIAS_Feature_Summary.csv"
feature_summary = pd.read_csv(feature_summary_file, sep=data_delimiter)

# %% [markdown]
# We clean the general demographics dataset.

# %%
# Load in the general demographics data.
general_demographics_file = "Udacity_AZDIAS_Subset.csv"
general_demographics = pd.read_csv(general_demographics_file, sep=data_delimiter)

clean_general_demographics = clean_data("general", general_demographics, feature_summary, data_delimiter, features_to_drop_list, missing_fields_threshold, log_interval)

# Save the result into a .csv file for later analysis as this step takes a long time to run.  
clean_general_demographics.to_csv("clean_general_demographics.csv", sep=data_delimiter, index=False)
# Out:
# row_index:  0
# row_index:  20000
# row_index:  40000
# row_index:  60000
# row_index:  80000
# row_index:  100000
# row_index:  120000
# row_index:  140000
# row_index:  160000
# row_index:  180000
# row_index:  200000
# row_index:  220000
# row_index:  240000
# row_index:  260000
# row_index:  280000
# row_index:  300000
# row_index:  320000
# row_index:  340000
# row_index:  360000
# row_index:  380000
# row_index:  400000
# row_index:  420000
# row_index:  440000
# row_index:  460000
# row_index:  480000
# row_index:  500000
# row_index:  520000
# row_index:  540000
# row_index:  560000
# row_index:  580000
# row_index:  600000
# row_index:  620000
# row_index:  640000
# row_index:  660000
# row_index:  680000
# row_index:  700000
# row_index:  720000
# row_index:  740000
# row_index:  760000
# row_index:  780000
# row_index:  800000
# row_index:  820000
# row_index:  840000
# row_index:  860000
# row_index:  880000
# replace_missing_values_with_nan time: 8:26:16.747905

# %% [markdown]
# We clean the customer demographics dataset.

# %%
# Load in the customer demographics data.
customer_demographics_file = "Udacity_CUSTOMERS_Subset.csv"
customer_demographics = pd.read_csv(customer_demographics_file, sep=data_delimiter)

clean_customer_demographics = clean_data("customer", customer_demographics, feature_summary, data_delimiter, features_to_drop_list, missing_fields_threshold, log_interval)

# Save the result into a .csv file for later analysis as this step takes a long time to run.  
clean_customer_demographics.to_csv("clean_customer_demographics.csv", sep=data_delimiter, index=False)
# Out:
# row_index:  0
# row_index:  20000
# row_index:  40000
# row_index:  60000
# row_index:  80000
# row_index:  100000
# row_index:  120000
# row_index:  140000
# row_index:  160000
# row_index:  180000
# replace_missing_values_with_nan time: 0:52:29.005438

# %% [markdown]
# ## Step 2: Feature Transformation
#
# ### Step 2.1: Apply Feature Scaling
#
# Before we apply dimensionality reduction techniques to the data, we need to perform feature scaling so that the principal component vectors are not influenced by the natural differences in scale for features. Starting from this part of the project, you'll want to keep an eye on the [API reference page for sklearn](http://scikit-learn.org/stable/modules/classes.html) to help you navigate to all of the classes and functions that you'll need. In this substep, you'll need to check the following:
#
# - sklearn requires that data not have missing values in order for its estimators to work properly. So, before applying the scaler to your data, make sure that you've cleaned the DataFrame of the remaining missing values. This can be as simple as just removing all data points with missing data, or applying an [Imputer](http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.Imputer.html) to replace all missing values. You might also try a more complicated procedure where you temporarily remove missing values in order to compute the scaling parameters before re-introducing those missing values and applying imputation. Think about how much missing data you have and what possible effects each approach might have on your analysis, and justify your decision in the discussion section below.
# - For the actual scaling function, a [StandardScaler](http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html) instance is suggested, scaling each feature to mean 0 and standard deviation 1.
# - For these classes, you can make use of the `.fit_transform()` method to both fit a procedure to the data as well as apply the transformation to the data at the same time. Don't forget to keep the fit sklearn objects handy, since you'll be applying them to the customer demographics data towards the end of the project.

# %%
# If you've not yet cleaned the dataset of all NaN values, then investigate and
# do that now.
clean_general_demographics = pd.read_csv("clean_general_demographics.csv", sep=data_delimiter)

# %%
clean_general_demographics.isnull().sum(axis="index").sort_values(ascending=False)
# Out:
# KKK                   64401
# REGIOTYP              64401
# W_KEIT_KIND_HH        58898
# KBA05_ANTG4           39495
# KBA05_ANTG3           39495
#                       ...
# ANZ_PERSONEN              0
# ANZ_TITEL                 0
# HH_EINKOMMEN_SCORE        0
# MIN_GEBAEUDEJAHR          0
# SEMIO_KRIT                0
# Length: 65, dtype: int64

# %% [markdown]
# Since we have missing values, we will use the `sklearn.impute.SimpleImputer` to impute the missing values with the mean value for each column. Since all the columns are numeric data, this strategy should work.

# %%
# Impute Nan values.
#
# From: https://scikit-learn.org/stable/modules/generated/sklearn.impute.SimpleImputer.html#sklearn.impute.SimpleImputer
#
# The imputation strategy.
#
# If “mean”, then replace missing values using the mean along each column. Can only be used with numeric data.
#
# If “median”, then replace missing values using the median along each column. Can only be used with numeric data.
#
# If “most_frequent”, then replace missing using the most frequent value along each column. Can be used with strings or numeric data.
#
# If “constant”, then replace missing values with fill_value. Can be used with strings or numeric data.
mean_imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputed_general_demographics = mean_imputer.fit_transform(clean_general_demographics)

# %%
df_imputed_general_demographics = pd.DataFrame(imputed_general_demographics, columns=clean_general_demographics.columns, index=clean_general_demographics.index)

# %%
df_imputed_general_demographics.isnull().sum(axis="index").sort_values(ascending=False)
# Out:
# CAMEO_INTL_2015_LIFESTAGE    0
# WOHNDAUER_2008               0
# HH_EINKOMMEN_SCORE           0
# ANZ_TITEL                    0
# ANZ_PERSONEN                 0
#                             ..
# KBA05_ANTG2                  0
# KBA05_ANTG1                  0
# MIN_GEBAEUDEJAHR             0
# KONSUMNAEHE                  0
# ALTERSKATEGORIE_GROB         0
# Length: 65, dtype: int64

# %% [markdown]
# We no longer have any null values.

# %% [markdown]
# Next, we will use the `sklearn.preprocessing.StandardScaler` to scale each feature to mean 0 and standard deviation 1.

# %%
# Apply feature scaling to the general population demographics data.
#
# From: https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html#sklearn.preprocessing.StandardScaler
#
# Standardize features by removing the mean and scaling to unit variance
from sklearn.preprocessing import StandardScaler
standard_scaler = StandardScaler()
standardized_general_demographics = standard_scaler.fit_transform(df_imputed_general_demographics)

# %%
df_standardized_general_demographics = pd.DataFrame(standardized_general_demographics, columns=df_imputed_general_demographics.columns, index=df_imputed_general_demographics.index)

# %% [markdown]
# We do a sanity check of the dataset by using the `shape` property and the `head()` method.

# %%
df_standardized_general_demographics.shape
# Out:
# (797384, 65)

# %%
df_standardized_general_demographics.head()
# Out:
#    ALTERSKATEGORIE_GROB  ANREDE_KZ  FINANZ_MINIMALIST  FINANZ_SPARER  \
# 0             -1.765688   0.958066          -1.494564       1.538148
# 1              0.201391   0.958066          -1.494564       0.864764
# 2              1.184930   0.958066           0.683207      -0.482005
# 3              0.201391  -1.043770           0.683207       0.191380
# 4             -1.765688   0.958066          -0.042717      -1.155389
#
#    FINANZ_VORSORGER  FINANZ_ANLEGER  FINANZ_UNAUFFAELLIGER  FINANZ_HAUSBAUER  \
# 0         -1.040654        1.466421               0.959646          1.338783
# 1         -1.766879       -0.570860               0.244947          1.338783
# 2          1.138023       -0.570860              -1.184450         -0.792048
# 3          0.411798       -1.249953               0.244947         -0.792048
# 4          1.138023       -0.570860              -0.469751          1.338783
#
#    GREEN_AVANTGARDE  HEALTH_TYP  ...  PLZ8_GBZ    ARBEIT  ORTSGR_KLS9  \
# ...

# %% [markdown]
# We save the standardized general demographics dataset for further analysis.

# %%
df_standardized_general_demographics.to_csv("standardized_general_demographics.csv", sep=data_delimiter, index=False)

# %% [markdown]
# ### Discussion 2.1: Apply Feature Scaling

# %% [markdown]
# A discussion of the preprocessing that took place during the `clean_data()` function shades light on the need to impute the data. During the `clean_data()` function, we used a missing field threshold of 25 for each row and replaced all missing values with a value of `np.nan`. During our analysis, we verify the existence of null data via the `isnull()` method on the dataframe.
#
# The documentation for the `sklearn.impute.SimpleImputer` reveals that all numeric data is a requirement for using the imputer class with the mean strategy. The documentation for the SimpleImputer is available at the following URL:
#
# - [https://scikit-learn.org/stable/modules/generated/sklearn.impute.SimpleImputer.html#sklearn.impute.SimpleImputer](https://scikit-learn.org/stable/modules/generated/sklearn.impute.SimpleImputer.html#sklearn.impute.SimpleImputer) .
#
# In the`clean_data()` function, we also convert all non-numeric features into numeric values via one-hot encoding. This preprocessing allows us to use the mean strategy of the SimpleImputer.
#
# With the dataset imputed, we proceed to use the `sklearn.preprocessing.StandardScaler` to normalize the data so that the natural differences in scale for features does not influence the principal component vectors. The documentation for the StandardScaler is available at the following URL:
#
# - https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html#sklearn.preprocessing.StandardScaler
#
# With the dataset imputed and scaled, the features are now ready for principal component analysis (PCA).

# %% [markdown]
# ### Step 2.2: Perform Dimensionality Reduction
#
# On your scaled data, you are now ready to apply dimensionality reduction techniques.
#
# - Use sklearn's [PCA](http://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html) class to apply principal component analysis on the data, thus finding the vectors of maximal variance in the data. To start, you should not set any parameters (so all components are computed) or set a number of components that is at least half the number of features (so there's enough features to see the general trend in variability).
# - Check out the ratio of variance explained by each principal component as well as the cumulative variance explained. Try plotting the cumulative or sequential values using matplotlib's [`plot()`](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html) function. Based on what you find, select a value for the number of transformed features you'll retain for the clustering part of the project.
# - Once you've made a choice for the number of components to keep, make sure you re-fit a PCA instance to perform the decided-on transformation.

# %%
# Apply PCA to the data.

# %% [markdown]
# We load the standardized general demographics dataset.

# %%
standardized_general_demographics =  pd.read_csv("standardized_general_demographics.csv", sep=data_delimiter)

# %%
standardized_general_demographics.shape
# Out:
# (797384, 65)

# %%
standardized_general_demographics.head()
# Out:
#    ALTERSKATEGORIE_GROB  ANREDE_KZ  FINANZ_MINIMALIST  FINANZ_SPARER  \
# 0             -1.765688   0.958066          -1.494564       1.538148
# 1              0.201391   0.958066          -1.494564       0.864764
# 2              1.184930   0.958066           0.683207      -0.482005
# 3              0.201391  -1.043770           0.683207       0.191380
# 4             -1.765688   0.958066          -0.042717      -1.155389
#
#    FINANZ_VORSORGER  FINANZ_ANLEGER  FINANZ_UNAUFFAELLIGER  FINANZ_HAUSBAUER  \
# 0         -1.040654        1.466421               0.959646          1.338783
# 1         -1.766879       -0.570860               0.244947          1.338783
# 2          1.138023       -0.570860              -1.184450         -0.792048
# 3          0.411798       -1.249953               0.244947         -0.792048
# 4          1.138023       -0.570860              -0.469751          1.338783
#
#    GREEN_AVANTGARDE  HEALTH_TYP  ...  PLZ8_GBZ    ARBEIT  ORTSGR_KLS9  \
# ...

# %% [markdown]
# We will use the `sklearn.decomposition.PCA` class to perform princial component analysis (PCA). The documentation for the PCA class is availabe at the following URL:
#
# - https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html

# %%
pca = PCA()
standardized_general_demographics_pca = pca.fit_transform(standardized_general_demographics)

# %% [markdown]
# The `scree_plot` is a slightly modified version taken from the `helper_functions.py` script from one of the labs in class.

# %%
# Investigate the variance accounted for by each principal component.

# From helper_functions.py
def scree_plot(pca):
    '''
    Creates a scree plot associated with the principal components

    INPUT: pca - the result of instantiation of PCA in scikit learn

    OUTPUT:
            No return value, but a plot is rendered.
    '''
    num_components=len(pca.explained_variance_ratio_)
    ind = np.arange(num_components)
    vals = pca.explained_variance_ratio_

    plt.figure(figsize=(10, 6))
    ax = plt.subplot(111)
    cumvals = np.cumsum(vals)
    ax.bar(ind, vals)
    ax.plot(ind, cumvals)
    for i in range(num_components):
        if i < 4:
            ax.annotate(r"%s%%" % ((str(vals[i]*100)[:4])), (ind[i]+0.2, vals[i]), va="bottom", ha="center", fontsize=12)

    ax.xaxis.set_tick_params(width=0)
    ax.yaxis.set_tick_params(width=2, length=12)

    ax.set_xlabel("Principal Component")
    ax.set_ylabel("Variance Explained (%)")
    plt.title('Explained Variance Per Principal Component')

# %%
scree_plot(pca)

# %% [markdown]
# To find a cut-off for the number of features to use, we will use the `pca.explained_variance_ratio_` arrary to find how many components are needed to explain 85% of the data.

# %% [markdown]
# We do some rounding of the data and exploration of this `pca.explained_variance_ratio_`.

# %%
explained_radiance_ratio_rounded = np.round(pca.explained_variance_ratio_,3)

# %%
len(explained_radiance_ratio_rounded)
# Out:
# 65

# %%
explained_radiance_ratio_rounded
# Out:
# array([0.166, 0.133, 0.093, 0.053, 0.041, 0.033, 0.029, 0.027, 0.024,
#        0.023, 0.021, 0.02 , 0.018, 0.018, 0.017, 0.016, 0.015, 0.014,
#        0.013, 0.013, 0.012, 0.012, 0.011, 0.011, 0.011, 0.009, 0.008,
#        0.007, 0.007, 0.007, 0.007, 0.006, 0.006, 0.006, 0.006, 0.006,
#        0.005, 0.005, 0.005, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004,
#        0.003, 0.003, 0.003, 0.003, 0.003, 0.003, 0.003, 0.003, 0.002,
#        0.002, 0.002, 0.002, 0.002, 0.002, 0.002, 0.001, 0.001, 0.001,
#        0.   , 0.   ])

# %%
explained_data = 0.85

# %% [markdown]
# We define a `find_number_of_components()` function below:

# %%
def find_number_of_components(my_explained_threshold, my_explained_radiance_ratio_array):
    my_components_to_use = 1
    my_explained_percentage = 0.0
    for my_components_to_use in range(1,len(my_explained_radiance_ratio_array)):
        my_explained_percentage = my_explained_radiance_ratio_array[0:my_components_to_use].sum()
        #print("components_to_use:", my_components_to_use, "explained_percentage:", my_explained_percentage)
        if my_explained_percentage > my_explained_threshold:
            break
    return my_components_to_use, my_explained_percentage

# %% [markdown]
# We call the `find_number_of_components()` function and save the number of components to use to the variable `components_to_use`.

# %%
explained_threshold = 0.85
components_to_use, explained_percentage = find_number_of_components(explained_threshold, explained_radiance_ratio_rounded)
print("Using {} components, we can explain {}% of the variability in the original data.".format(components_to_use,explained_percentage))
# Out:
# Using 26 components, we can explain 0.853% of the variability in the original data.

# %% [markdown]
# We instantiate a new PCA object passing in as an argument the `components_to_use` for PCA analaysis.

# %%
# Re-apply PCA to the data while selecting for number of components to retain.
general_pca = PCA(n_components=components_to_use)
reduced_standardized_general_demographics_pca = general_pca.fit_transform(standardized_general_demographics)

# %% [markdown]
# We use the `scree_plot()` function to visualize the explained variance per principal component.

# %%
scree_plot(general_pca)

# %%
df_reduced_standardized_general_demographics_pca = pd.DataFrame(reduced_standardized_general_demographics_pca)

# %%
df_reduced_standardized_general_demographics_pca.shape
# Out:
# (797384, 26)

# %%
df_reduced_standardized_general_demographics_pca.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  3.848575 -2.673177 -2.903137 -0.166447 -2.110486  2.564932  1.115426
# 1 -0.976948  0.222063 -3.101571  2.314760 -0.257459  0.523769 -1.002511
# 2 -3.897155  1.337009 -0.756885 -0.675593 -0.115740 -0.210485  0.436143
# 3  0.542630  0.221224  3.247089  0.723155  0.376827 -3.483627  0.189215
# 4 -0.760004 -1.359969 -1.058199 -1.483528 -3.308642  0.087361 -1.090352
#
#          7         8         9   ...         16        17        18        19  \
# 0  0.814958 -0.732684 -1.092511  ...  10.863954 -0.091416  0.010366  1.024444
# 1 -0.489537 -0.804800 -1.237487  ...  -0.183175  1.704351  1.000617 -0.971679
# 2 -0.618531  0.064008  0.250612  ...  -0.030028  0.072922 -1.047882  0.558790
# 3  1.804338 -1.486546 -0.361299  ...  -0.234202  0.146463 -0.176872 -0.526323
# 4 -0.632405  3.711046 -0.375295  ...   0.044900 -2.185903 -0.203190 -0.423428
#
#          20        21        22        23        24        25
# ...

# %%
general_pca.components_
# Out:
# array([[-0.1134889 ,  0.00848295, -0.21716652, ...,  0.10776768,
#          0.20835614, -0.12452794],
#        [ 0.26228257,  0.08915383,  0.07127455, ...,  0.01177945,
#          0.06975366,  0.00505463],
#        [ 0.07868338, -0.3688032 ,  0.15634208, ..., -0.04455257,
#          0.02693247, -0.00798459],
#        ...,
#        [ 0.02759309,  0.00404781, -0.03059551, ..., -0.00398654,
#         -0.01231934, -0.08946063],
#        [-0.08004029,  0.04634121, -0.09784749, ..., -0.07629407,
#          0.03107339,  0.06162182],
#        [-0.04808737,  0.02899272, -0.17704251, ...,  0.0339691 ,
#         -0.13546503, -0.11003555]])

# %% [markdown]
# We save the reduced and standardized general demographics dataset for further analysis.

# %%
df_reduced_standardized_general_demographics_pca.to_csv("reduced_standardized_general_demographics_pca.csv", sep=data_delimiter, index=False)

# %% [markdown]
# ### Discussion 2.2: Perform Dimensionality Reduction

# %% [markdown]
# In order to perform dimensionality reduction, the genearal demographics dataset was first fitted and transformed with a default PCA object. A scree plot was used to visualize the explained variance of the cumulative principal components. The `pca.explained_variance_ratio_` array of the default PCA object was used to find the number of components needed to explain at least 85% of the variability in the data. It was determined that 26 components were required. A new PCA object with n_components=26 was instantiated. It was used to fit and transform the general demographics dataset. We have been able to reduce the features from 65 to 26.

# %% [markdown]
# ### Step 2.3: Interpret Principal Components
#
# Now that we have our transformed principal components, it's a nice idea to check out the weight of each variable on the first few components to see if they can be interpreted in some fashion.
#
# As a reminder, each principal component is a unit vector that points in the direction of highest variance (after accounting for the variance captured by earlier principal components). The further a weight is from zero, the more the principal component is in the direction of the corresponding feature. If two features have large weights of the same sign (both positive or both negative), then increases in one tend expect to be associated with increases in the other. To contrast, features with different signs can be expected to show a negative correlation: increases in one variable should result in a decrease in the other.
#
# - To investigate the features, you should map each weight to their corresponding feature name, then sort the features according to weight. The most interesting features for each principal component, then, will be those at the beginning and end of the sorted list. Use the data dictionary document to help you understand these most prominent features, their relationships, and what a positive or negative value on the principal component might indicate.
# - You should investigate and interpret feature associations from the first three principal components in this substep. To help facilitate this, you should write a function that you can call at any time to print the sorted list of feature weights, for the *i*-th principal component. This might come in handy in the next step of the project, when you interpret the tendencies of the discovered clusters.

# %%
# Map weights for the first principal component to corresponding feature names
# and then print the linked values, sorted by weight.
# HINT: Try defining a function here or in a new cell that you can reuse in the
# other cells.

# %% [markdown]
# We read the standardized general demographics dataset.

# %%
standardized_general_demographics =  pd.read_csv("standardized_general_demographics.csv", sep=data_delimiter)

# %% [markdown]
# The `pca_results()` function from one of the classroom labs has been slightly modified to helps us visualize that each PCA dimension is a weighted function of the features. For readablility, we only graph the first dimension and the 26 weights.

# %%
# Taken from helper_functions.py
def pca_results(full_dataset, pca):
    '''
    Create a DataFrame of the PCA results
    Includes dimension feature weights and explained variance
    Visualizes the PCA results
    '''

    # Dimension indexing
    dimensions = dimensions = ['Dimension {}'.format(i) for i in range(1,len(pca.components_)+1)]

    # PCA components
    components = pd.DataFrame(np.round(pca.components_, 4), columns = full_dataset.keys())
    components.index = dimensions

    # PCA explained variance
    ratios = pca.explained_variance_ratio_.reshape(len(pca.components_), 1)
    variance_ratios = pd.DataFrame(np.round(ratios, 4), columns = ['Explained Variance'])
    variance_ratios.index = dimensions

    # Create a bar plot visualization
    fig, ax = plt.subplots(figsize = (20,20))

    # Plot the feature weights as a function of the components
    components[:1].plot(ax = ax, kind = 'bar');
    #ax.get_legend().set_visible(False)
    ax.set_ylabel("Feature Weights")
    ax.set_xticklabels(dimensions[:1], rotation=0)

    # Display the explained variance ratios
    #for i, ev in enumerate(pca.explained_variance_ratio_):
    #    ax.text(i-0.40, ax.get_ylim()[1] + 0.05, "Explained Variance\n          %.4f"%(ev))

    # Return a concatenated DataFrame
    return pd.concat([variance_ratios, components], axis = 1)

# %%
pca_results(standardized_general_demographics, general_pca)
# Out:
#               Explained Variance  ALTERSKATEGORIE_GROB  ANREDE_KZ  \
# Dimension 1               0.1661               -0.1135     0.0085
# Dimension 2               0.1326                0.2623     0.0892
# Dimension 3               0.0933                0.0787    -0.3688
# Dimension 4               0.0530               -0.0396     0.0299
# Dimension 5               0.0408               -0.0098     0.0237
# Dimension 6               0.0325                0.0005     0.0243
# Dimension 7               0.0292               -0.0018    -0.0236
# Dimension 8               0.0268                0.0595    -0.0498
# Dimension 9               0.0238               -0.1519     0.0420
# Dimension 10              0.0228                0.0585     0.0863
# Dimension 11              0.0206                0.0751     0.0324
# Dimension 12              0.0202               -0.1073     0.0128
# Dimension 13              0.0184                0.0152    -0.0185
# ...

# %% [markdown]
# We now define a function to map the weights for a given component.

# %%
def map_weight(my_df, my_pca, component):
    my_pca_df = pd.DataFrame(my_pca.components_, columns=list(my_df.columns))
    my_pca_component = pd.DataFrame(my_pca_df.iloc[component])
    print(my_pca_component.sort_values(component, ascending=False))

# %% [markdown]
# We take a look at the weights for the first component.

# %%
map_weight(standardized_general_demographics, general_pca, 0)
# Out:
#                                0
# PLZ8_ANTG3              0.227825
# PLZ8_ANTG4              0.221317
# CAMEO_INTL_2015_WEALTH  0.208356
# HH_EINKOMMEN_SCORE      0.204450
# ORTSGR_KLS9             0.197984
# ...                          ...
# FINANZ_MINIMALIST      -0.217167
# KBA05_GBZ              -0.217937
# KBA05_ANTG1            -0.226803
# PLZ8_ANTG1             -0.228097
# MOBI_REGIO             -0.242895
#
# [65 rows x 1 columns]

# %%
# Map weights for the second principal component to corresponding feature names
# and then print the linked values, sorted by weight.

# %% [markdown]
# We take a look at the weights for the second component.

# %%
map_weight(standardized_general_demographics, general_pca, 1)
# Out:
#                                      1
# ALTERSKATEGORIE_GROB          0.262283
# FINANZ_VORSORGER              0.234526
# SEMIO_ERL                     0.231448
# SEMIO_LUST                    0.184872
# RETOURTYP_BK_S                0.163766
# ...                                ...
# SEMIO_PFLICHT                -0.230109
# SEMIO_TRADV                  -0.232965
# FINANZ_SPARER                -0.238739
# PRAEGENDE_JUGENDJAHRE_DECADE -0.253307
# SEMIO_REL                    -0.256411
#
# [65 rows x 1 columns]

# %% [markdown]
# We take a look at the weights for the third component.

# %%
# Map weights for the third principal component to corresponding feature names
# and then print the linked values, sorted by weight.

# %%
map_weight(standardized_general_demographics, general_pca, 2)
# Out:
#                           2
# SEMIO_VERT         0.345495
# SEMIO_SOZ          0.262559
# SEMIO_FAM          0.250196
# SEMIO_KULT         0.235707
# FINANZ_MINIMALIST  0.156342
# ...                     ...
# SEMIO_RAT         -0.217515
# SEMIO_KRIT        -0.276370
# SEMIO_DOM         -0.314659
# SEMIO_KAEM        -0.337504
# ANREDE_KZ         -0.368803
#
# [65 rows x 1 columns]

# %% [markdown]
# ### Discussion 2.3: Interpret Principal Components

# %% [markdown]
# We will look at the first 3 principal components and try to interpret relationships from the top 3 positive and negative weights. In general, if two features have large weights of the same sign (both positive or both negative), then increases in one tend to be associated with increases in the other, i.e. a positive correlation. In contrast, features with different signs can be expected to show a negative correlation: increases in one variable should result in a decrease in the other. Using this guidance, we will analyze the first 3 components.

# %% [markdown]
# ### Analysis for Principle Component 0

# %% [markdown]
# For principle component 0, the top 3 positive weights were the following:
#
# - PLZ8_ANTG3 - Number of 6-10 family houses in the PLZ8 region
#     - 0: no 6-10 family homes
#     - 1: lower share of 6-10 family homes
#     - 2: average share of 6-10 family homes
#     - 3: high share of 6-10 family homes
# - PLZ8_ANTG4 - Number of 10+ family houses in the PLZ8 region
#     - 0: no 10+ family homes
#     - 1: lower share of 10+ family homes
#     - 2: high share of 10+ family homes
# - CAMEO_INTL_2015_WEALTH - Wealth mapped to international code
#     - 1: Wealthy Households
#     - 2: Properous Households
#     - 3: Comfortable Households
#     - 4: Less Affluent Households
#     - 5: Poorer Households
#
# A positive correlation in the first principle component exists between large households (PLZ8_ANTG3, PLZ8_ANTG4) and wealth (CAMEO_INTL_2015_WEALTH). This correlation can be interpreted as wealthy households tend to have a high number of household members.
#
# For principle component 0, the top 3 negative weights were the following:
#
# - MOBI_REGIO - Movement patterns
#     - 1: very high movement
#     - 2: high movement
#     - 3: middle movement
#     - 4: low movement
#     - 5: very low movement
#     - 6: none
# - PLZ8_ANTG1 - Number of 1-2 family houses in the PLZ8 region
#     - 0: no 1-2 family homes
#     - 1: lower share of 1-2 family homes
#     - 2: average share of 1-2 famiy homes
#     - 3: high share of 1-2 family homes
#     - 4: very high share of 1-2 family homes
# - KBA05_ANTG1 - Number of 1-2 family houses in the microcell
#     - 0: no 1-2 family homes
#     - 1: lower share of 1-2 family homes
#     - 2: avearge share of 1-2 family homes
#     - 3: high share of 1-2 family homes
#     - 4: very high share of 1-2 family homes.
#
# A positive correlation for principle component 0 exists between small family households (PLZ8_ANT1, KBA05_ANTG1) and movement patterns (MOBI_REGIO). This correlation can be interpreted as small households tend to have low movement.
#
# A negative correlation for principle component 0 exists between large family households (PLZ8_ANTG3, PLZ8_ANTG4) and small family households (PLZ8_ANT1, KBA05_ANTG1). This correlation can be interpreted as people that live in large family households tend to not live in small family households.

# %% [markdown]
# ### Analysis for Principle Component 1

# %% [markdown]
# For principle component 1, the top 3 positive weights were the following:
#
# - ALTERSKATEGORIE_GROB - Estimated age based on given name analysis
#     - 0: unknown (cannot be determined)
#     - 1: < 30 years old
#     - 2: 30-45 years old
#     - 3: 46-60 years old
#     - 4: > 60 years old
#     - 9: uniformly distributed
# - FINANZ_VORSORGER - Financial Typology of be prepared
#     - 1: very high
#     - 2: high
#     - 3: average
#     - 4: low
#     - 5: very low
# - SEMIO_ERL - Personality Typology of event-oriented
#     - 1: highest affininity
#     - 2: very high affinity
#     - 3: high affinity
#     - 4: average affinity
#     - 5: low affinity
#     - 6: very low affinity
#     - 7: lowest affinity
#     - 9: unknown
#
# A positive correlation for principle component 1 exists between financial typology of be prepared (FINANZ_VORSORGER) and personality of type event-oriented (SEMIO_ERL). This correlation can be interpreted as individuals who have a financialy typology of be prepared tend to have a personality typology of event-oriented.
#
# For principle component 1, the top 3 negative weights were the following:
#
# - SEMIO_REL - Personality typology of religious
#     - 1: highest affinity
#     - 2: very high affinity
#     - 3: high affinity
#     - 4: avearge affinity
#     - 5: low affinity
#     - 6: very low affinity
#     - 7: lowest affinity
#     - 9: unknown
# - PRAEGENDE_JUGENDJAHRE_DECADE - Dominating decade of person's youth
#     - 1, 2: 40s
#     - 3, 4: 50s
#     - 5, 6, 7: 60s
#     - 8, 9: 70s
#     - 10, 11, 12, 13: 80s
#     - 14, 15: 90s
# - FINANZ_SPARER - Financial typology of money-saver
#     - 1: very high
#     - 2: high
#     - 3: average
#     - 4: low
#     - 5: very low
#
# A positive correlation for principle component 1 exists between the decade of their youth (PRAEGENDE_JUGENDJAHRE_DECADE) and their attitudes towards religion (SEMIO_REL) and money (FINAZ_SPARER). This correlation can be interpreted as an individual's youth tends to shape their views towards religion and money.
#
# A negative correlation for principle component 1 exists between a personality typology of event-oriented (SEMIO_ERL) and personality typology of religious (SEMIO_REL). This correlation can be interpreted as an individual is either event-oriented or religious, but not usually both.

# %% [markdown]
# ### Analysis for Principle Component 2

# %% [markdown]
# For principle component 2, the top 3 positive weights were the following:
#
# - SEMIO_VERT - Personality typology of dreamful
#     - 1: highest affinity
#     - 2: very high affinity
#     - 3: high affinity
#     - 4: avearge affinity
#     - 5: low affinity
#     - 6: very low affinity
#     - 7: lowest affinity
#     - 9: unknown
# - SEMIO_SOZ - Personality typology of socially-minded
#     - 1: highest affinity
#     - 2: very high affinity
#     - 3: high affinity
#     - 4: avearge affinity
#     - 5: low affinity
#     - 6: very low affinity
#     - 7: lowest affinity
#     - 9: unknown
# - SEMIO_FAM - Personality typology of family-minded
#     - 1: highest affinity
#     - 2: very high affinity
#     - 3: high affinity
#     - 4: avearge affinity
#     - 5: low affinity
#     - 6: very low affinity
#     - 7: lowest affinity
#     - 9: unknown
#
# A positive correlation for principle component 2 exists between the personality typology of family-minded (SEMIO_FAM) and a personality typology of socially-minded (SEMIO_SOZ). This correlation can be interpreted as individuals with a personality typology of family-minded tend to have a personality typology of socially-minded.
#
# For principle component 2, the top 3 negative weights were the following:
#
# - ANREDE_KZ - Gender
#     - 0: unknown
#     - 1: male
#     - 2: female
# - SEMIO_KAEM - Personality typology of combative attitude
#     - 1: highest affinity
#     - 2: very high affinity
#     - 3: high affinity
#     - 4: avearge affinity
#     - 5: low affinity
#     - 6: very low affinity
#     - 7: lowest affinity
#     - 9: unknown
# - SEMIO_DOM - Personality typlogy of dominant-minded
#     - 1: highest affinity
#     - 2: very high affinity
#     - 3: high affinity
#     - 4: avearge affinity
#     - 5: low affinity
#     - 6: very low affinity
#     - 7: lowest affinity
#     - 9: unknown
#
# A positive correlation for principle component 2 exists betwen personality typology of combativie attitude (SEMIO_KAEM) and a personality typlogy of dominant-minded (SEMO_DOM). This correlation can be interpreted as individuals with a personality typology of combatitive attidude also tend to have a personality typology of dominant-minded.
#
# A negative correlation for principle component 2 exists between personality typlogy of socially-minded (SEMIO_SOZ) and a personality typology of combative attitude (SEMO_KAEM). This correlation can be interpreted as individual who exhibit a personality typology of socially-minded are usually not of a personality typology of combative attitude.

# %% [markdown]
# ## Step 3: Clustering
#
# ### Step 3.1: Apply Clustering to General Population
#
# You've assessed and cleaned the demographics data, then scaled and transformed them. Now, it's time to see how the data clusters in the principal components space. In this substep, you will apply k-means clustering to the dataset and use the average within-cluster distances from each point to their assigned cluster's centroid to decide on a number of clusters to keep.
#
# - Use sklearn's [KMeans](http://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html#sklearn.cluster.KMeans) class to perform k-means clustering on the PCA-transformed data.
# - Then, compute the average difference from each point to its assigned cluster's center. **Hint**: The KMeans object's `.score()` method might be useful here, but note that in sklearn, scores tend to be defined so that larger is better. Try applying it to a small, toy dataset, or use an internet search to help your understanding.
# - Perform the above two steps for a number of different cluster counts. You can then see how the average distance decreases with an increasing number of clusters. However, each additional cluster provides a smaller net benefit. Use this fact to select a final number of clusters in which to group the data. **Warning**: because of the large size of the dataset, it can take a long time for the algorithm to resolve. The more clusters to fit, the longer the algorithm will take. You should test for cluster counts through at least 10 clusters to get the full picture, but you shouldn't need to test for a number of clusters above about 30.
# - Once you've selected a final number of clusters to use, re-fit a KMeans instance to perform the clustering operation. Make sure that you also obtain the cluster assignments for the general demographics data, since you'll be using them in the final Step 3.3.

# %%
from sklearn.cluster import KMeans

def get_kmeans_score(data, center):
    '''
    returns the kmeans score regarding SSE for points to centers
    INPUT:
        data - the dataset you want to fit kmeans to
        center - the number of centers you want (the k value)
    OUTPUT:
        score - the SSE score for the kmeans model fit to the data
    '''
    #instantiate kmeans
    kmeans = KMeans(n_clusters=center)

    # Then fit the model to your data using the fit method
    model = kmeans.fit(data)
    
    # Obtain a score related to the model fit
    score = np.abs(model.score(data))
    
    return score

# %%
# Investigate the change in within-cluster distance across number of clusters.
# HINT: Use matplotlib's plot function to visualize this relationship.

scores = []
centers = list(range(1,20))

start_time = time.time()

for center in centers:
    scores.append(get_kmeans_score(df_reduced_standardized_general_population_data_pca, center))
    
end_time = time.time()
my_seconds = end_time - start_time
my_time_delta = str(datetime.timedelta(seconds=my_seconds))
print("Time to run get_kmeans_score across different number of clusters: {}".format(my_time_delta))
# Out:
# Time to run get_kmeans_score across different number of clusters: 0:24:01.484218

# %%
plt.plot(centers, scores, linestyle='--', marker='o', color='b');
plt.xlabel('K');
plt.ylabel('SSE');
plt.title('SSE vs. K');

# %%
# Re-fit the k-means model with the selected number of clusters and obtain
# cluster predictions for the general population demographics data.

kmeans = KMeans(n_clusters=7)
general_population_model = kmeans.fit(df_reduced_standardized_general_population_data_pca)

# %%
general_population_predictions = general_population_model.predict(df_reduced_standardized_general_population_data_pca)

# %%
general_population_predictions.shape
# Out:
# (797384,)

# %%
df_general_population_predictions = pd.DataFrame(general_population_predictions)

# %%
df_general_population_predictions.head()
# Out:
#    0
# 0  6
# 1  0
# 2  0
# 3  2
# 4  1

# %%
cluster_ids = list(range(0,7))
cluster_sizes = []

for cluster_id in cluster_ids:
    cluster_size = df_general_population_predictions[df_general_population_predictions[0] == cluster_id].count()
    print("cluster_id:", cluster_id, "cluster_size:", cluster_size[0])
    cluster_sizes.append(cluster_size[0])
# Out:
# cluster_id: 0 cluster_size: 132244
# cluster_id: 1 cluster_size: 106213
# cluster_id: 2 cluster_size: 111389
# cluster_id: 3 cluster_size: 142070
# cluster_id: 4 cluster_size: 110983
# cluster_id: 5 cluster_size: 89519
# cluster_id: 6 cluster_size: 104966

# %%
cluster_ids
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
cluster_sizes
# Out:
# [132244, 106213, 111389, 142070, 110983, 89519, 104966]

# %%
plt.bar(cluster_ids, cluster_sizes);
plt.xlabel('Cluster ID');
plt.ylabel('Cluster Size');
plt.title('General Population Clusters');
plt.show()

# %% [markdown]
# ### Discussion 3.1: Apply Clustering to General Population
#
# (Double-click this cell and replace this text with your own text, reporting your findings and decisions regarding clustering. Into how many clusters have you decided to segment the population?)

# %% [markdown]
# ### Step 3.2: Apply All Steps to the Customer Data
#
# Now that you have clusters and cluster centers for the general population, it's time to see how the customer data maps on to those clusters. Take care to not confuse this for re-fitting all of the models to the customer data. Instead, you're going to use the fits from the general population to clean, transform, and cluster the customer data. In the last step of the project, you will interpret how the general population fits apply to the customer data.
#
# - Don't forget when loading in the customers data, that it is semicolon (`;`) delimited.
# - Apply the same feature wrangling, selection, and engineering steps to the customer demographics using the `clean_data()` function you created earlier. (You can assume that the customer demographics data has similar meaning behind missing data patterns as the general demographics data.)
# - Use the sklearn objects from the general demographics data, and apply their transformations to the customers data. That is, you should not be using a `.fit()` or `.fit_transform()` method to re-fit the old objects, nor should you be creating new sklearn objects! Carry the data through the feature scaling, PCA, and clustering steps, obtaining cluster assignments for all of the data in the customer demographics data.

# %%
# Load in the customer demographics data.
customer_population_file = "Udacity_CUSTOMERS_Subset.csv"
customer_population_data = pd.read_csv(customer_population_file, sep=data_delimiter)

# %%
# Apply preprocessing, feature transformation, and clustering from the general
# demographics onto the customer data, obtaining cluster predictions for the
# customer demographics data.

# %%
clean_customer_population_data = clean_data("customer", customer_population_data, feature_information, data_delimiter, features_to_drop_list, missing_fields_threshold)

# %%
# Save the result into a new df as this step takes a long time to run  
clean_customer_population_data.to_csv("clean_customer_population_data.csv", sep=data_delimiter, index=False)

# %%
clean_customer_population_data = pd.read_csv("clean_customer_population_data.csv", sep=data_delimiter)

# %%
clean_customer_population_data.isnull().sum(axis="index").sort_values(ascending=False)
# Out:
# KKK                   10076
# REGIOTYP              10076
# W_KEIT_KIND_HH         7892
# KBA05_GBZ              5972
# KBA05_ANTG3            5970
#                       ...
# MIN_GEBAEUDEJAHR          0
# ANZ_PERSONEN              0
# ANZ_TITEL                 0
# HH_EINKOMMEN_SCORE        0
# SEMIO_RAT                 0
# Length: 65, dtype: int64

# %%
mean_imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputed_customer_population_data = mean_imputer.fit_transform(clean_customer_population_data)

# %%
df_imputed_customer_population_data = pd.DataFrame(imputed_customer_population_data, columns=clean_customer_population_data.columns, index=clean_customer_population_data.index)

# %%
df_imputed_customer_population_data.isnull().sum(axis="index").sort_values(ascending=False)
# Out:
# CAMEO_INTL_2015_LIFESTAGE    0
# WOHNDAUER_2008               0
# HH_EINKOMMEN_SCORE           0
# ANZ_TITEL                    0
# ANZ_PERSONEN                 0
#                             ..
# KBA05_ANTG2                  0
# KBA05_ANTG1                  0
# MIN_GEBAEUDEJAHR             0
# KONSUMNAEHE                  0
# ALTERSKATEGORIE_GROB         0
# Length: 65, dtype: int64

# %%
standardized_customer_population_data = scaler.fit_transform(df_imputed_customer_population_data)

# %%
df_standardized_customer_population_data = pd.DataFrame(standardized_customer_population_data, columns=df_imputed_customer_population_data.columns, index=df_imputed_customer_population_data.index)

# %%
df_standardized_customer_population_data.shape
# Out:
# (141642, 65)

# %%
df_standardized_customer_population_data.head()
# Out:
#    ALTERSKATEGORIE_GROB  ANREDE_KZ  FINANZ_MINIMALIST  FINANZ_SPARER  \
# 0              0.703103  -0.702888           0.723084      -0.516975
# 1              0.703103   1.422703           0.723084      -0.516975
# 2              0.703103  -0.702888           0.723084      -0.516975
# 3             -0.668032  -0.702888          -1.241771      -0.516975
# 4             -0.668032  -0.702888           0.723084      -0.516975
#
#    FINANZ_VORSORGER  FINANZ_ANLEGER  FINANZ_UNAUFFAELLIGER  FINANZ_HAUSBAUER  \
# 0          0.516197       -0.600706               0.137753         -0.553327
# 1          0.516197       -0.600706               2.182351          0.965615
# 2          0.516197        0.396986              -0.884546         -0.553327
# 3         -0.665463        2.392370               3.204650         -0.553327
# 4          0.516197       -0.600706               0.137753          0.206144
#
#    GREEN_AVANTGARDE  HEALTH_TYP  ...  PLZ8_GBZ    ARBEIT  ORTSGR_KLS9  \
# ...

# %%
# Transform the customer population data using the pca object from the general population data.
reduced_standardized_customer_population_data_pca = pca.fit_transform(df_standardized_customer_population_data)

# %%
df_reduced_standardized_customer_population_data_pca = pd.DataFrame(reduced_standardized_customer_population_data_pca)

# %%
df_reduced_standardized_customer_population_data_pca.shape
# Out:
# (141642, 26)

# %%
df_reduced_standardized_customer_population_data_pca.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -3.821418 -2.874305 -1.645312 -0.033862  2.724470  2.349978  0.484456
# 1  3.281124  0.789628 -3.229421  1.964546 -0.617604 -0.447011 -1.013239
# 2 -2.767683 -0.266091 -0.690961 -3.601368  0.723217 -0.789290  0.848736
# 3  2.415363  1.080159  4.665925 -1.621784  0.030410 -0.466389 -2.492517
# 4 -0.251809 -1.683058  0.429540  1.451009  2.159047 -1.259318 -1.205361
#
#          7         8         9   ...        16        17        18        19  \
# 0 -0.295523 -0.941745 -0.547602  ...  0.185081  0.332063 -0.182905 -1.013539
# 1  1.350390 -0.602545 -0.595409  ...  0.326995 -0.675417 -0.958110 -0.804963
# 2  0.248473  0.086956 -0.410606  ...  0.215165 -0.765895 -0.474021  1.080128
# 3  1.125832 -1.156740  1.844325  ... -0.333500  0.078297  0.055508 -0.968268
# 4 -1.569159  0.143700  0.783201  ...  0.432153  0.290080 -0.845962  0.900417
#
#          20        21        22        23        24        25
# ...

# %%
# Predict clustering using the general population model
customer_population_predictions = general_population_model.predict(df_reduced_standardized_customer_population_data_pca)

# %%
customer_population_predictions
# Out:
# array([1, 4, 0, ..., 1, 4, 3])

# %%
customer_population_predictions == 3
# Out:
# array([False, False, False, ..., False, False,  True])

# %%
df_reduced_standardized_customer_population_data_pca
# Out:
#               0         1         2         3         4         5         6   \
# 0      -3.821418 -2.874305 -1.645312 -0.033862  2.724470  2.349978  0.484456
# 1       3.281124  0.789628 -3.229421  1.964546 -0.617604 -0.447011 -1.013239
# 2      -2.767683 -0.266091 -0.690961 -3.601368  0.723217 -0.789290  0.848736
# 3       2.415363  1.080159  4.665925 -1.621784  0.030410 -0.466389 -2.492517
# 4      -0.251809 -1.683058  0.429540  1.451009  2.159047 -1.259318 -1.205361
# ...          ...       ...       ...       ...       ...       ...       ...
# 141637  0.159730 -2.867905  1.136769  4.028592  1.583240 -2.151943  0.471813
# 141638  0.163526  3.349001 -3.112842 -1.583144  1.660225  0.582200 -0.786309
# 141639 -1.454969 -1.306476 -2.512281  0.766948 -0.399120  0.695124 -2.030830
# 141640  2.935204  2.655941 -1.391399 -0.124777 -0.933717 -1.464547  0.720987
# 141641 -3.781716  0.379562  2.780142 -2.443921  2.773545 -3.043037  1.813195
#
# ...

# %%
df_reduced_standardized_customer_population_data_pca[customer_population_predictions == 3]
# Out:
#               0         1         2         3         4         5         6   \
# 8      -2.762945  0.374475  2.091866  2.536380  0.369442 -0.075498 -2.248260
# 9      -3.926988 -2.092183  0.614611  0.572967  0.999090  1.321835  2.777320
# 10     -4.453085  1.670816  0.493996 -3.738035  0.762565  1.573331 -0.892091
# 11     -1.058872  1.376640  2.068103 -0.896611 -0.985277  0.187180 -2.851737
# 13     -3.832648 -1.487544  0.844644  2.339216  2.592325  0.616990  0.824360
# ...          ...       ...       ...       ...       ...       ...       ...
# 141614 -1.899454 -2.369889  1.549334  0.836275  1.429564 -0.061475  0.060326
# 141629 -1.603390  1.859295  4.372577 -0.652845 -2.007988  0.238478  0.482998
# 141630 -1.761605 -1.803363  1.624144  3.335411  1.625953 -1.087505  0.329149
# 141631 -4.535244 -2.546819 -0.637139 -0.384981  1.392539  1.252206  1.063044
# 141641 -3.781716  0.379562  2.780142 -2.443921  2.773545 -3.043037  1.813195
#
# ...

# %%
df_customer_population_predictions = pd.DataFrame(customer_population_predictions)

# %%
df_customer_population_predictions.shape
# Out:
# (141642, 1)

# %%
df_customer_population_predictions.head()
# Out:
#    0
# 0  1
# 1  4
# 2  0
# 3  2
# 4  1

# %%
customer_cluster_ids = list(range(0,7))
customer_cluster_sizes = []

for cluster_id in customer_cluster_ids:
    customer_cluster_size = df_customer_population_predictions[df_customer_population_predictions[0] == cluster_id].count()
    print("cluster_id:", cluster_id, "customer_cluster_size:", customer_cluster_size[0])
    customer_cluster_sizes.append(customer_cluster_size[0])
# Out:
# cluster_id: 0 customer_cluster_size: 20834
# cluster_id: 1 customer_cluster_size: 20105
# cluster_id: 2 customer_cluster_size: 12909
# cluster_id: 3 customer_cluster_size: 33682
# cluster_id: 4 customer_cluster_size: 19540
# cluster_id: 5 customer_cluster_size: 14493
# cluster_id: 6 customer_cluster_size: 20079

# %%
customer_cluster_ids
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
customer_cluster_sizes
# Out:
# [20834, 20105, 12909, 33682, 19540, 14493, 20079]

# %%
plt.bar(customer_cluster_ids, customer_cluster_sizes);
plt.xlabel('Cluster ID');
plt.ylabel('Customer Cluster Size');
plt.title('Customer Population Clusters');
plt.show()

# %% [markdown]
# ### Step 3.3: Compare Customer Data to Demographics Data
#
# At this point, you have clustered data based on demographics of the general population of Germany, and seen how the customer data for a mail-order sales company maps onto those demographic clusters. In this final substep, you will compare the two cluster distributions to see where the strongest customer base for the company is.
#
# Consider the proportion of persons in each cluster for the general population, and the proportions for the customers. If we think the company's customer base to be universal, then the cluster assignment proportions should be fairly similar between the two. If there are only particular segments of the population that are interested in the company's products, then we should see a mismatch from one to the other. If there is a higher proportion of persons in a cluster for the customer data compared to the general population (e.g. 5% of persons are assigned to a cluster for the general population, but 15% of the customer data is closest to that cluster's centroid) then that suggests the people in that cluster to be a target audience for the company. On the other hand, the proportion of the data in a cluster being larger in the general population than the customer data (e.g. only 2% of customers closest to a population centroid that captures 6% of the data) suggests that group of persons to be outside of the target demographics.
#
# Take a look at the following points in this step:
#
# - Compute the proportion of data points in each cluster for the general population and the customer data. Visualizations will be useful here: both for the individual dataset proportions, but also to visualize the ratios in cluster representation between groups. Seaborn's [`countplot()`](https://seaborn.pydata.org/generated/seaborn.countplot.html) or [`barplot()`](https://seaborn.pydata.org/generated/seaborn.barplot.html) function could be handy.
#   - Recall the analysis you performed in step 1.1.3 of the project, where you separated out certain data points from the dataset if they had more than a specified threshold of missing values. If you found that this group was qualitatively different from the main bulk of the data, you should treat this as an additional data cluster in this analysis. Make sure that you account for the number of data points in this subset, for both the general population and customer datasets, when making your computations!
# - Which cluster or clusters are overrepresented in the customer dataset compared to the general population? Select at least one such cluster and infer what kind of people might be represented by that cluster. Use the principal component interpretations from step 2.3 or look at additional components to help you make this inference. Alternatively, you can use the `.inverse_transform()` method of the PCA and StandardScaler objects to transform centroids back to the original data space and interpret the retrieved values directly.
# - Perform a similar investigation for the underrepresented clusters. Which cluster or clusters are underrepresented in the customer dataset compared to the general population, and what kinds of people are typified by these clusters?

# %%
# Compare the proportion of data in each cluster for the customer data to the
# proportion of data in each cluster for the general population.
number_of_clusters = 7
general_population_proportion = []
customer_population_proportion = []

size_of_general_population_predictions = len(df_general_population_predictions)
size_of_customer_population_predictions = len(df_customer_population_predictions)

population_clusters = list(range(number_of_clusters))

for i in population_clusters:
    general_population_proportion.append((df_general_population_predictions == i).sum()[0]/size_of_general_population_predictions)
    customer_population_proportion.append((df_customer_population_predictions == i).sum()[0]/size_of_customer_population_predictions)

# %%
df_proportions = pd.DataFrame({'population_clusters' : population_clusters, 'general_population_proportion' : general_population_proportion, 'customer_population_proportion': customer_population_proportion})

# %%
df_proportions.shape
# Out:
# (7, 3)

# %%
df_proportions
# Out:
#    population_clusters  general_population_proportion  \
# 0                    0                       0.165847
# 1                    1                       0.133202
# 2                    2                       0.139693
# 3                    3                       0.178170
# 4                    4                       0.139184
# 5                    5                       0.112266
# 6                    6                       0.131638
#
#    customer_population_proportion
# 0                        0.147089
# 1                        0.141942
# 2                        0.091138
# 3                        0.237797
# 4                        0.137953
# 5                        0.102321
# 6                        0.141759

# %%
df_proportions.plot(x='population_clusters', y = ['general_population_proportion', 'customer_population_proportion'], kind='bar', figsize=(9,6))
plt.ylabel('proportion of persons in each cluster')
plt.show()

# %%
# Check difference in cluster proportion for general vs customer populations
diff_customer_proportions = df_proportions["customer_population_proportion"] - df_proportions["general_population_proportion"]

# %%
diff_customer_proportions.shape
# Out:
# (7,)

# %%
diff_customer_proportions
# Out:
# 0   -0.018758
# 1    0.008741
# 2   -0.048555
# 3    0.059627
# 4   -0.001230
# 5   -0.009945
# 6    0.010121
# dtype: float64

# %%
diff_customer_proportions.sort_values(ascending=False,inplace=True)

# %%
print("over-represented")
# Out:
# over-represented

# %%
print(diff_customer_proportions[:3])
# Out:
# 3    0.059627
# 6    0.010121
# 1    0.008741
# dtype: float64

# %%
print("under-represented")
# Out:
# under-represented

# %%
print(diff_customer_proportions[-3:])
# Out:
# 5   -0.009945
# 0   -0.018758
# 2   -0.048555
# dtype: float64

# %%
# What kinds of people are part of a cluster that is overrepresented in the
# customer data compared to the general population?

# %%
def plot_cluster_demographics(k, pca_features, kmeans_labels, features):
    pca_cluster = pca_features[kmeans_labels == k]

    print('cluster', k, 'accounts for', np.round(pca_cluster.shape[0]*100/features.shape[0],3), '% of population')

    standardized_features = pca.inverse_transform(pca_cluster)
    features_cluster1 = scaler.inverse_transform(standardized_features)

    features_cluster1 = pd.DataFrame(np.round(features_cluster1), columns = features.columns)

    fig, axs = plt.subplots(2,3, figsize=(18,8))
    sns.countplot(features_cluster1['HH_EINKOMMEN_SCORE'], ax = axs[0,0], color='#33A1C9')
    sns.countplot(features_cluster1['CAMEO_INTL_2015_WEALTH'], ax = axs[0,1], color='#33A1C9')
    sns.countplot(features_cluster1['KBA05_ANTG1'], ax = axs[0,2], color='#33A1C9')
    sns.countplot(features_cluster1['ALTERSKATEGORIE_GROB'], ax = axs[1,0], color='#33A1C9')
    sns.countplot(features_cluster1['ANREDE_KZ'], ax = axs[1,1], color='#33A1C9')
    sns.countplot(features_cluster1['MOBI_REGIO'], ax = axs[1,2], color='#33A1C9')
    plt.show();

# %% [markdown]
# HH_EINKOMMEN_SCORE - Estimated household net income
# - 0: Unknown
# - 1: highest income
# - 2: very high income
# - 3: high income
# - 4: average income
# - 5: lower income
# - 6: very low income

# %% [markdown]
# CAMEO_INTL_2015 - Wealth
# - 0: Unknown
# - 1: Wealthy Households
# - 2: Prosperoous Households
# - 3: Comfortable Households
# - 4: Less affluent Households
# - 5: Poorer Households

# %%
plot_cluster_demographics(k=3, pca_features=df_reduced_standardized_customer_population_data_pca, kmeans_labels=customer_population_predictions, features=df_standardized_customer_population_data)
# Out:
# cluster 3 accounts for 23.78 % of population

# %% [markdown]
# The over-represented group seems to belong primarily to:
# - HH_EINKOMMEN_SCORE: 2, very high income.
# - CAMEO_INTL_2015: 2, Prosperoous Households
# - KBA05_ANTG1: 3, high share of 1-2 family homes
# - ALTERSKATEGORIE_GROB: 3, 46-60 years old
# - ANDREDE_KZ: 1, male
# - MOBI_REGIO: 4, low movement

# %%
# What kinds of people are part of a cluster that is underrepresented in the
# customer data compared to the general population?
plot_cluster_demographics(k=2, pca_features=df_reduced_standardized_customer_population_data_pca, kmeans_labels=customer_population_predictions, features=df_standardized_customer_population_data)
# Out:
# cluster 2 accounts for 9.114 % of population

# %% [markdown]
# The under-represented group seems to belong primarily to:
#  - HH_EINKOMMEN_SCORE: 5, lower income
#  - CAMEO_INTL_2015_WEALTH: 3, comfortable households
#  - KBA05_ANTG1: 0, no 1-2 family homes
#  - ALTERSKATEGORIE_GROB: 3, 46-60 years old
#  - ANREDE_KZ: 1, male
#  - MOBI_REGIO: 2, high movement

# %% [markdown]
# ### Discussion 3.3: Compare Customer Data to Demographics Data
#
# (Double-click this cell and replace this text with your own text, reporting findings and conclusions from the clustering analysis. Can we describe segments of the population that are relatively popular with the mail-order company, or relatively unpopular with the company?)

# %% [markdown]
# > Congratulations on making it this far in the project! Before you finish, make sure to check through the entire notebook from top to bottom to make sure that your analysis follows a logical flow and all of your findings are documented in **Discussion** cells. Once you've checked over all of your work, you should export the notebook as an HTML document to submit for evaluation. You can do this from the menu, navigating to **File -> Download as -> HTML (.html)**. You will submit both that document and this notebook for your project submission.
